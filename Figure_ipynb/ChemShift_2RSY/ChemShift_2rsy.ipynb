# %% [markdown]
# ## Make secondary chemical shift plot

# %%
# Import and defination

import matplotlib.pyplot as plt
import numpy as numpy
from ChemShift import *

# %%
# Test Block and Experiment Data

CAShift_sim1_A = LoadPred_CA("2rsy.md.pdb_pred_sim1_A.tab")
CAShift2_sim1_A = LoadPred_CA_2("2rsy.md.pdb_pred_sim1_A.tab")
CAShift_RC_sim1_A = LoadPred_CA_RC("2rsy.md.pdb_pred_sim1_A.tab")

CAShift_sim1_B = LoadPred_CA("2rsy.md.pdb_pred_sim1_B.tab")
CAShift2_sim1_B = LoadPred_CA_2("2rsy.md.pdb_pred_sim1_B.tab")
CAShift_RC_sim1_B = LoadPred_CA_RC("2rsy.md.pdb_pred_sim1_B.tab")

res_list = LoadPred_Res("2rsy.md.pdb_pred_sim1_A.tab") + LoadPred_Res("2rsy.md.pdb_pred_sim1_B.tab")

ExpData_Raw_A = [None,63.174,55.639,45.327,58.431,52.164,65.259,52.896,57.172,56.404,46.832,56.108,60.064,61.169,61.172,59.735,58.88,55.027,60.611,58.555,56.715,52.676,55.985,None,63.508,55.905,65.209,46.015,54.774,56.022,54.809,61.185,52.621,57.679,57.946,66.304,54.312,55.613,64.054,45.511,53.138,56.641,61.859,53.733,56.353,58.962,57.492,54.985,56.89,45.399,54.156,62.21,54.608,55.087,56.772,57.086,60.263,56.505,55.659,55.32,53.293,60.231,54.692,53.455,59.072,62.461,53.326,58.706,57.387,60.724,56.087,56.151,57.957,52.172,57.271,60.226,58.205,58.805,66.877,59.949,59.899,59.977,64.618,64.74,53.216,55.451,54.137,44.808,54.428,58.139,59.768,56.199,54.906,62.789,52.597,61.368,53.654,61.462,58.154]

ExpData_Raw_B = [None,63.164,55.509,45.381,58.393,56.273,56.297,57.592,58.184,58.52,54.967,58.506,58.629,54.765,55.719,57.713,58.027,57.047,50.665,63.536,62.097,55.718,60.095,59.32,60.004,59.266,64.902,62.092,53.386,56.342,57.664,59.217,57.23,62.606,52.392,54.273,63.503,46.138]

print(len(CAShift_sim1_A))
print(len(ExpData_Raw_A))

print(len(CAShift_sim1_B))
print(len(ExpData_Raw_B))

ExpData_A = [ExpData_Raw_A[i]-CAShift_RC_sim1_A[i] if ExpData_Raw_A[i] != None else None for i in range(len(CAShift_RC_sim1_A))]
ExpData_B = [ExpData_Raw_B[i]-CAShift_RC_sim1_B[i] if ExpData_Raw_B[i] != None else None for i in range(len(CAShift_RC_sim1_B))]

ExpData = ExpData_A + ExpData_B
# Out:
# 99
# 99
# 38
# 38

# %%
# Load 4 kinds of chemical shift data, all secondary chemical shift

CAShift2_sim1 = LoadPred_CA_2("2rsy.md.pdb_pred_sim1_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_sim1_B.tab")
CAShift2_sim2 = LoadPred_CA_2("2rsy.md.pdb_pred_sim2_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_sim2_B.tab")
CAShift2_sim3 = LoadPred_CA_2("2rsy.md.pdb_pred_sim3_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_sim3_B.tab")
CAShift2_sim4 = LoadPred_CA_2("2rsy.md.pdb_pred_sim4_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_sim4_B.tab")
CAShift2_sim5 = LoadPred_CA_2("2rsy.md.pdb_pred_sim5_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_sim5_B.tab")

AvgShift = [(CAShift2_sim1[i]+CAShift2_sim2[i]+CAShift2_sim3[i]+CAShift2_sim4[i]+CAShift2_sim5[i])/5 for i in range(len(CAShift2_sim1))]

CAShift2_CMAP_sim1 = LoadPred_CA_2("2rsy.md.pdb_pred_CMAP_sim1_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_CMAP_sim1_B.tab")
CAShift2_CMAP_sim2 = LoadPred_CA_2("2rsy.md.pdb_pred_CMAP_sim2_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_CMAP_sim2_B.tab")
CAShift2_CMAP_sim3 = LoadPred_CA_2("2rsy.md.pdb_pred_CMAP_sim3_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_CMAP_sim3_B.tab")
CAShift2_CMAP_sim4 = LoadPred_CA_2("2rsy.md.pdb_pred_CMAP_sim4_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_CMAP_sim4_B.tab")
CAShift2_CMAP_sim5 = LoadPred_CA_2("2rsy.md.pdb_pred_CMAP_sim5_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_CMAP_sim5_B.tab")

AvgShift_CMAP = [(CAShift2_CMAP_sim1[i]+CAShift2_CMAP_sim2[i]+CAShift2_CMAP_sim3[i]+CAShift2_CMAP_sim4[i]+CAShift2_CMAP_sim5[i])/5 for i in range(len(CAShift2_CMAP_sim1))]

CAShift2_D_sim1 = LoadPred_CA_2("2rsy.md.pdb_pred_D_sim1_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_D_sim1_B.tab")
CAShift2_D_sim2 = LoadPred_CA_2("2rsy.md.pdb_pred_D_sim2_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_D_sim2_B.tab")
CAShift2_D_sim3 = LoadPred_CA_2("2rsy.md.pdb_pred_D_sim3_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_D_sim3_B.tab")
CAShift2_D_sim4 = LoadPred_CA_2("2rsy.md.pdb_pred_D_sim4_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_D_sim4_B.tab")
CAShift2_D_sim5 = LoadPred_CA_2("2rsy.md.pdb_pred_D_sim5_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_D_sim5_B.tab")

AvgShift_D = [(CAShift2_D_sim1[i]+CAShift2_D_sim2[i]+CAShift2_D_sim3[i]+CAShift2_D_sim4[i]+CAShift2_D_sim5[i])/5 for i in range(len(CAShift2_D_sim1))]

CAShift2_D_CMAP_sim1 = LoadPred_CA_2("2rsy.md.pdb_pred_D_CMAP_sim1_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_D_CMAP_sim1_B.tab")
CAShift2_D_CMAP_sim2 = LoadPred_CA_2("2rsy.md.pdb_pred_D_CMAP_sim2_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_D_CMAP_sim2_B.tab")
CAShift2_D_CMAP_sim3 = LoadPred_CA_2("2rsy.md.pdb_pred_D_CMAP_sim3_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_D_CMAP_sim3_B.tab")
CAShift2_D_CMAP_sim4 = LoadPred_CA_2("2rsy.md.pdb_pred_D_CMAP_sim4_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_D_CMAP_sim4_B.tab")
CAShift2_D_CMAP_sim5 = LoadPred_CA_2("2rsy.md.pdb_pred_D_CMAP_sim5_A.tab") + LoadPred_CA_2("2rsy.md.pdb_pred_D_CMAP_sim5_B.tab")

AvgShift_D_CMAP = [(CAShift2_D_CMAP_sim1[i]+CAShift2_D_CMAP_sim2[i]+CAShift2_D_CMAP_sim3[i]+CAShift2_D_CMAP_sim4[i]+CAShift2_D_CMAP_sim5[i])/5 for i in range(len(CAShift2_D_CMAP_sim1))]

# %%
# Plotting!

plt.subplots(figsize=(24,4))

plt.plot(AvgShift,'.-',label='ffptm TIP4Pew',color="tab:blue")
plt.plot(AvgShift_CMAP,'.-',label='ff03CMAP TIP4Pew',color="tab:orange")
plt.plot(AvgShift_D,'.-',label='ffptm TIP4PD',color="tab:green")
plt.plot(AvgShift_D_CMAP,'.-',label='ff03CMAP TIP4PD',color="tab:red")

plt.plot(ExpData,'.-',label='Experiment',color="black")



plt.title('Cα Chemical shift of 2RSY',loc='left')

plt.xlim(0, len(AvgShift)-1)
plt.xticks(np.arange(0,len(res_list)),res_list,rotation='90')

# Tag modified residues
plt.axvline(x=129, ymin=0, ymax=1,color="grey",linestyle="--")

plt.legend()
plt.savefig("ChemShift_2rsy.png",dpi=300)
plt.show()

# %%
print(RMSD(AvgShift,ExpData))
print(RMSD(AvgShift_CMAP,ExpData))
print(RMSD(AvgShift_D,ExpData))
print(RMSD(AvgShift_D_CMAP,ExpData))
# Out:
# 1.0900358615884491
# 1.0777842113873213
# 1.1798756358575364
# 1.110783323280556

# %%
print(RMSD(AvgShift,ExpData))
print(RMSD(AvgShift_CMAP,ExpData))
print(RMSD(AvgShift_D,ExpData))
print(RMSD(AvgShift_D_CMAP,ExpData))

plt.subplots(figsize=(4,3.5))

RMSD_1 = RMSD(AvgShift,ExpData)
RMSD_2 = RMSD(AvgShift_CMAP,ExpData)
RMSD_3 = RMSD(AvgShift_D,ExpData)
RMSD_4 = RMSD(AvgShift_D_CMAP,ExpData)

color=['tab:blue','tab:orange','tab:green','tab:red']
x_label=['PTM 4EW','CMAP 4EW','PTM 4D','CMAP 4D']
plt.xticks([1,3,5,7], x_label,rotation='30')
plt.bar([1,3,5,7], [RMSD_1,RMSD_2,RMSD_3,RMSD_4],color=color)

plt.tight_layout()

# plt.savefig("2lkj_bar.png",dpi=100)
plt.show()
# Out:
# 1.0900358615884491
# 1.0777842113873213
# 1.1798756358575364
# 1.110783323280556

# %% [markdown]
# ## Make FF score

# %%
ExpData_CA = [None,63.174,55.639,45.327,58.431,52.164,65.259,52.896,57.172,56.404,46.832,56.108,60.064,61.169,61.172,59.735,58.88,55.027,60.611,58.555,56.715,52.676,55.985,None,63.508,55.905,65.209,46.015,54.774,56.022,54.809,61.185,52.621,57.679,57.946,66.304,54.312,55.613,64.054,45.511,53.138,56.641,61.859,53.733,56.353,58.962,57.492,54.985,56.89,45.399,54.156,62.21,54.608,55.087,56.772,57.086,60.263,56.505,55.659,55.32,53.293,60.231,54.692,53.455,59.072,62.461,53.326,58.706,57.387,60.724,56.087,56.151,57.957,52.172,57.271,60.226,58.205,58.805,66.877,59.949,59.899,59.977,64.618,64.74,53.216,55.451,54.137,44.808,54.428,58.139,59.768,56.199,54.906,62.789,52.597,61.368,53.654,61.462,58.154,None,63.164,55.509,45.381,58.393,56.273,56.297,57.592,58.184,58.52,54.967,58.506,58.629,54.765,55.719,57.713,58.027,57.047,50.665,63.536,62.097,55.718,60.095,59.32,60.004,59.266,64.902,62.092,53.386,56.342,57.664,59.217,57.23,62.606,52.392,54.273,63.503,46.138]
ExpData_CB = [None,32.293,42.161,None,63.633,32.981,31.858,30.001,39.318,33.213,None,30.738,40.429,71.179,28.63,28.927,28.489,19.006,28.205,30.04,42.804,40.041,None,42.124,32,32.166,68.851,None,44.631,45.014,44.907,35.376,34.701,30.424,62.986,69.012,37.303,37.341,31.499,None,42.031,42.774,70.746,43.79,29.241,35.974,63.893,46.343,27.448,None,35.241,32.395,30.769,33.803,40.304,30.795,38.04,33.921,39.127,30.91,16.537,62.491,37.041,46.212,67.063,39.929,42.499,27.791,32.132,33.165,42.297,43.555,31.048,40.446,43.649,31.224,29.715,41.78,31.504,29.255,28.981,37.819,69.282,69.126,44.564,18.305,40.248,None,42.303,41.395,68.112,30.503,38.036,40.396,35.961,32.772,30.897,32.856,33.245,None,32.352,42.324,None,63.985,32.913,30.939,39.879,64.362,63.86,43.287,63.762,40.037,36.546,64.714,30.164,29.425,30.748,41.29,32.317,69.258,43.602,71.799,28.779,29.199,29.975,38.112,62.849,18.593,32.077,41.189,62.621,65.305,32.905,39.493,32.681,32.155,None]
ExpData_C = [None,177.093,177.892,173.978,173.873,None,None,175.871,174.992,174.807,174.223,175.743,175.991,174.976,177.576,178.967,178.748,178.374,178.815,178.973,178.027,172.549,None,None,176.376,174.442,175.858,174.287,176.738,171.878,174.665,173.398,175.939,176.217,176.669,175.645,174.991,None,178.797,173.075,176.467,173.303,172.909,174.192,173.079,173.007,174.542,173.723,176.028,173.332,173.795,175.348,174.064,174.164,175.343,174.971,174.86,175.766,175.466,173.984,176.416,173.201,174.547,177.624,173.233,176.896,176.449,173.957,175.769,173.96,174.785,175.583,176.431,175.01,177.973,178.776,178.734,177.437,179.036,179.073,176.892,175.876,175.562,174.148,172.421,178.533,174.523,176.158,177.515,172.956,170.41,176.126,175.822,176.327,None,176.262,175.182,175.754,None,None,177.061,178.048,174.29,174.618,176.264,175.938,175.565,174.108,174.241,176.977,173.259,175.262,173.183,176.736,177.351,177.754,176.673,None,177.892,175.342,177.563,175.569,179.709,179.336,178.495,179.282,177.12,178.156,175.048,174.988,172.966,174.558,175.401,173.852,None,176.472,None]
ExpData_HN = [None,None,8.54,8.296,8.015,8.124,None,5.58,7.852,8.696,5.202,9.024,6.894,8.827,9.153,8.671,7.98,8.215,8.359,7.706,7.603,7.098,7.193,None,None,7.13,8.686,9.165,8.165,8.334,9.214,9.427,9.277,8.321,8.328,7.964,10.571,8.182,None,9.056,8.106,8.641,9.75,9.671,9.235,8.874,8.644,9.295,9.228,9.137,7.859,8.137,8.921,7.7,9.877,9.539,9.515,8.633,8.959,8.773,9.032,8.112,7.872,9.063,8.462,9.772,8.141,8.532,8.471,9.38,8.3,9.312,8.976,7.546,9.046,8.3,8.375,6.83,8.101,8.273,7.708,7.448,7.619,7.137,7.392,8.343,8.081,8.336,8.279,7.695,7.213,7.516,8.132,8.382,7.846,None,8.881,8.046,7.874,None,None,8.579,8.461,8.225,8.341,8.255,8.361,8.19,8.507,8.068,8.274,8.239,6.952,8.399,9.224,7.958,7.298,7.674,None,8.183,6.979,8.8,8.986,8.83,7.667,8.127,8.435,7.264,8.285,8.043,9.073,8.693,8.812,8.952,8.552,None,8.017]
ExpData_HA = [None,4.448,4.253,None,4.327,3.899,4.218,4.725,5.612,4.682,None,4.484,4.75,4.085,3.484,3.858,3.873,3.786,3.77,3.924,4.161,4.313,4.148,None,4.101,4.239,4.008,None,5.628,6.135,4.921,5.437,5.366,4.44,4.443,4.256,4.526,4.869,4.164,None,5.235,5.325,5.342,4.983,5.281,5.213,4.91,4.634,3.869,None,4.744,4.433,4.282,5.1,5.054,4.399,4.155,4.085,5.573,4.569,3.831,3.967,5.12,5.838,4.506,4.769,4.543,3.218,4.403,4.217,4.911,5.03,4.448,4.613,3.835,4.28,4.043,1.98,2.902,3.849,4.132,4.945,4.661,3.992,4.428,3.742,4.164,None,4.05,4.308,4.36,4.325,3.757,4.202,5.015,3.425,4.578,4.33,3.883,None,4.481,4.352,None,4.431,4.295,4.222,4.705,4.487,4.515,4.412,4.37,4.488,4.064,4.751,4.118,3.989,4.224,5.005,4.684,4.337,4.196,4.533,4.035,4.119,3.928,4.004,4.446,4.507,4.55,4.872,4.462,5.015,4.014,4.944,4.56,4.422,None]
ExpData_N = [None,None,122.492,108.721,114.315,119.748,None,108.528,124.259,125.424,103.606,129.645,116.991,113.457,120.936,118.62,119.136,120.932,114.4,118.102,118.504,120.368,119.723,None,None,122.711,123.934,113.848,127.031,122.521,113.638,119.542,122.56,122.194,119.028,125.144,122.337,120.156,None,116.162,119.654,117.145,117.281,129.431,128.49,121.713,120.515,126.529,123.556,105.022,120.603,120.379,127.617,120.554,123.024,126.493,128.36,125.874,126.525,124.499,130.602,106.542,120.173,119.648,112.074,125.283,118.277,114.384,118.121,122.58,126.571,117.359,118.819,108.539,118.256,119.635,118.781,121.953,120.435,121.197,118.183,115.595,116.251,115.949,120.205,124.511,110.978,102.658,119.615,114.661,113.726,121.049,122.103,121.408,121.527,None,125.349,124.806,127.655,None,None,122.584,109.899,115.741,123.207,122.109,120.995,116.899,117.791,124.235,117.541,122.271,126.832,116.118,126.684,116.866,117.327,115.87,None,109.842,123.247,114.497,119.968,119.764,120.687,118.774,114.883,120.842,116.213,120.677,119.116,117.256,121.687,124.491,124.424,None,115.387]

print(len(ExpData_CA),len(ExpData_CB),len(ExpData_C),len(ExpData_HN),len(ExpData_HA),len(ExpData_N))
# Out:
# 137 137 137 137 137 137

# %%
# CA
Avg_CAShift = AvgChemShift_CA("2rsy.md.pdb_pred_sim1_A.tab","2rsy.md.pdb_pred_sim2_A.tab","2rsy.md.pdb_pred_sim3_A.tab","2rsy.md.pdb_pred_sim4_A.tab","2rsy.md.pdb_pred_sim5_A.tab") + AvgChemShift_CA("2rsy.md.pdb_pred_sim1_B.tab","2rsy.md.pdb_pred_sim2_B.tab","2rsy.md.pdb_pred_sim3_B.tab","2rsy.md.pdb_pred_sim4_B.tab","2rsy.md.pdb_pred_sim5_B.tab")
Avg_CAShift_CMAP = AvgChemShift_CA("2rsy.md.pdb_pred_CMAP_sim1_A.tab","2rsy.md.pdb_pred_CMAP_sim2_A.tab","2rsy.md.pdb_pred_CMAP_sim3_A.tab","2rsy.md.pdb_pred_CMAP_sim4_A.tab","2rsy.md.pdb_pred_CMAP_sim5_A.tab") + AvgChemShift_CA("2rsy.md.pdb_pred_CMAP_sim1_B.tab","2rsy.md.pdb_pred_CMAP_sim2_B.tab","2rsy.md.pdb_pred_CMAP_sim3_B.tab","2rsy.md.pdb_pred_CMAP_sim4_B.tab","2rsy.md.pdb_pred_CMAP_sim5_B.tab")
Avg_CAShift_D = AvgChemShift_CA("2rsy.md.pdb_pred_D_sim1_A.tab","2rsy.md.pdb_pred_D_sim2_A.tab","2rsy.md.pdb_pred_D_sim3_A.tab","2rsy.md.pdb_pred_D_sim4_A.tab","2rsy.md.pdb_pred_D_sim5_A.tab") + AvgChemShift_CA("2rsy.md.pdb_pred_D_sim1_B.tab","2rsy.md.pdb_pred_D_sim2_B.tab","2rsy.md.pdb_pred_D_sim3_B.tab","2rsy.md.pdb_pred_D_sim4_B.tab","2rsy.md.pdb_pred_D_sim5_B.tab")
Avg_CAShift_D_CMAP = AvgChemShift_CA("2rsy.md.pdb_pred_D_CMAP_sim1_A.tab","2rsy.md.pdb_pred_D_CMAP_sim2_A.tab","2rsy.md.pdb_pred_D_CMAP_sim3_A.tab","2rsy.md.pdb_pred_D_CMAP_sim4_A.tab","2rsy.md.pdb_pred_D_CMAP_sim5_A.tab") + AvgChemShift_CA("2rsy.md.pdb_pred_D_CMAP_sim1_B.tab","2rsy.md.pdb_pred_D_CMAP_sim2_B.tab","2rsy.md.pdb_pred_D_CMAP_sim3_B.tab","2rsy.md.pdb_pred_D_CMAP_sim4_B.tab","2rsy.md.pdb_pred_D_CMAP_sim5_B.tab")

print('ffptm EW CA ',RMSD(Avg_CAShift,ExpData_CA))
print('ff03CMAP EW CA ',RMSD(Avg_CAShift_CMAP,ExpData_CA))
print('ffptm D CA ',RMSD(Avg_CAShift_D,ExpData_CA))
print('ff03CMAP D CA ',RMSD(Avg_CAShift_D_CMAP,ExpData_CA))


# CB
Avg_CBShift = AvgChemShift_CB("2rsy.md.pdb_pred_sim1_A.tab","2rsy.md.pdb_pred_sim2_A.tab","2rsy.md.pdb_pred_sim3_A.tab","2rsy.md.pdb_pred_sim4_A.tab","2rsy.md.pdb_pred_sim5_A.tab") + AvgChemShift_CB("2rsy.md.pdb_pred_sim1_B.tab","2rsy.md.pdb_pred_sim2_B.tab","2rsy.md.pdb_pred_sim3_B.tab","2rsy.md.pdb_pred_sim4_B.tab","2rsy.md.pdb_pred_sim5_B.tab")
Avg_CBShift_CMAP = AvgChemShift_CB("2rsy.md.pdb_pred_CMAP_sim1_A.tab","2rsy.md.pdb_pred_CMAP_sim2_A.tab","2rsy.md.pdb_pred_CMAP_sim3_A.tab","2rsy.md.pdb_pred_CMAP_sim4_A.tab","2rsy.md.pdb_pred_CMAP_sim5_A.tab") + AvgChemShift_CB("2rsy.md.pdb_pred_CMAP_sim1_B.tab","2rsy.md.pdb_pred_CMAP_sim2_B.tab","2rsy.md.pdb_pred_CMAP_sim3_B.tab","2rsy.md.pdb_pred_CMAP_sim4_B.tab","2rsy.md.pdb_pred_CMAP_sim5_B.tab")
Avg_CBShift_D = AvgChemShift_CB("2rsy.md.pdb_pred_D_sim1_A.tab","2rsy.md.pdb_pred_D_sim2_A.tab","2rsy.md.pdb_pred_D_sim3_A.tab","2rsy.md.pdb_pred_D_sim4_A.tab","2rsy.md.pdb_pred_D_sim5_A.tab") + AvgChemShift_CB("2rsy.md.pdb_pred_D_sim1_B.tab","2rsy.md.pdb_pred_D_sim2_B.tab","2rsy.md.pdb_pred_D_sim3_B.tab","2rsy.md.pdb_pred_D_sim4_B.tab","2rsy.md.pdb_pred_D_sim5_B.tab")
Avg_CBShift_D_CMAP = AvgChemShift_CB("2rsy.md.pdb_pred_D_CMAP_sim1_A.tab","2rsy.md.pdb_pred_D_CMAP_sim2_A.tab","2rsy.md.pdb_pred_D_CMAP_sim3_A.tab","2rsy.md.pdb_pred_D_CMAP_sim4_A.tab","2rsy.md.pdb_pred_D_CMAP_sim5_A.tab") + AvgChemShift_CB("2rsy.md.pdb_pred_D_CMAP_sim1_B.tab","2rsy.md.pdb_pred_D_CMAP_sim2_B.tab","2rsy.md.pdb_pred_D_CMAP_sim3_B.tab","2rsy.md.pdb_pred_D_CMAP_sim4_B.tab","2rsy.md.pdb_pred_D_CMAP_sim5_B.tab")

print('ffptm EW CB ',RMSD(Avg_CBShift,ExpData_CB))
print('ff03CMAP EW CB ',RMSD(Avg_CBShift_CMAP,ExpData_CB))
print('ffptm D CB ',RMSD(Avg_CBShift_D,ExpData_CB))
print('ff03CMAP D CB ',RMSD(Avg_CBShift_D_CMAP,ExpData_CB))


# C
Avg_CShift = AvgChemShift_C("2rsy.md.pdb_pred_sim1_A.tab","2rsy.md.pdb_pred_sim2_A.tab","2rsy.md.pdb_pred_sim3_A.tab","2rsy.md.pdb_pred_sim4_A.tab","2rsy.md.pdb_pred_sim5_A.tab") + AvgChemShift_C("2rsy.md.pdb_pred_sim1_B.tab","2rsy.md.pdb_pred_sim2_B.tab","2rsy.md.pdb_pred_sim3_B.tab","2rsy.md.pdb_pred_sim4_B.tab","2rsy.md.pdb_pred_sim5_B.tab")
Avg_CShift_CMAP = AvgChemShift_C("2rsy.md.pdb_pred_CMAP_sim1_A.tab","2rsy.md.pdb_pred_CMAP_sim2_A.tab","2rsy.md.pdb_pred_CMAP_sim3_A.tab","2rsy.md.pdb_pred_CMAP_sim4_A.tab","2rsy.md.pdb_pred_CMAP_sim5_A.tab") + AvgChemShift_C("2rsy.md.pdb_pred_CMAP_sim1_B.tab","2rsy.md.pdb_pred_CMAP_sim2_B.tab","2rsy.md.pdb_pred_CMAP_sim3_B.tab","2rsy.md.pdb_pred_CMAP_sim4_B.tab","2rsy.md.pdb_pred_CMAP_sim5_B.tab")
Avg_CShift_D = AvgChemShift_C("2rsy.md.pdb_pred_D_sim1_A.tab","2rsy.md.pdb_pred_D_sim2_A.tab","2rsy.md.pdb_pred_D_sim3_A.tab","2rsy.md.pdb_pred_D_sim4_A.tab","2rsy.md.pdb_pred_D_sim5_A.tab") + AvgChemShift_C("2rsy.md.pdb_pred_D_sim1_B.tab","2rsy.md.pdb_pred_D_sim2_B.tab","2rsy.md.pdb_pred_D_sim3_B.tab","2rsy.md.pdb_pred_D_sim4_B.tab","2rsy.md.pdb_pred_D_sim5_B.tab")
Avg_CShift_D_CMAP = AvgChemShift_C("2rsy.md.pdb_pred_D_CMAP_sim1_A.tab","2rsy.md.pdb_pred_D_CMAP_sim2_A.tab","2rsy.md.pdb_pred_D_CMAP_sim3_A.tab","2rsy.md.pdb_pred_D_CMAP_sim4_A.tab","2rsy.md.pdb_pred_D_CMAP_sim5_A.tab") + AvgChemShift_C("2rsy.md.pdb_pred_D_CMAP_sim1_B.tab","2rsy.md.pdb_pred_D_CMAP_sim2_B.tab","2rsy.md.pdb_pred_D_CMAP_sim3_B.tab","2rsy.md.pdb_pred_D_CMAP_sim4_B.tab","2rsy.md.pdb_pred_D_CMAP_sim5_B.tab")

print('ffptm EW C ',RMSD(Avg_CShift,ExpData_C))
print('ff03CMAP EW C ',RMSD(Avg_CShift_CMAP,ExpData_C))
print('ffptm D C ',RMSD(Avg_CShift_D,ExpData_C))
print('ff03CMAP D C ',RMSD(Avg_CShift_D_CMAP,ExpData_C))


# HA
Avg_HAShift = AvgChemShift_HA("2rsy.md.pdb_pred_sim1_A.tab","2rsy.md.pdb_pred_sim2_A.tab","2rsy.md.pdb_pred_sim3_A.tab","2rsy.md.pdb_pred_sim4_A.tab","2rsy.md.pdb_pred_sim5_A.tab") + AvgChemShift_HA("2rsy.md.pdb_pred_sim1_B.tab","2rsy.md.pdb_pred_sim2_B.tab","2rsy.md.pdb_pred_sim3_B.tab","2rsy.md.pdb_pred_sim4_B.tab","2rsy.md.pdb_pred_sim5_B.tab")
Avg_HAShift_CMAP = AvgChemShift_HA("2rsy.md.pdb_pred_CMAP_sim1_A.tab","2rsy.md.pdb_pred_CMAP_sim2_A.tab","2rsy.md.pdb_pred_CMAP_sim3_A.tab","2rsy.md.pdb_pred_CMAP_sim4_A.tab","2rsy.md.pdb_pred_CMAP_sim5_A.tab") + AvgChemShift_HA("2rsy.md.pdb_pred_CMAP_sim1_B.tab","2rsy.md.pdb_pred_CMAP_sim2_B.tab","2rsy.md.pdb_pred_CMAP_sim3_B.tab","2rsy.md.pdb_pred_CMAP_sim4_B.tab","2rsy.md.pdb_pred_CMAP_sim5_B.tab")
Avg_HAShift_D = AvgChemShift_HA("2rsy.md.pdb_pred_D_sim1_A.tab","2rsy.md.pdb_pred_D_sim2_A.tab","2rsy.md.pdb_pred_D_sim3_A.tab","2rsy.md.pdb_pred_D_sim4_A.tab","2rsy.md.pdb_pred_D_sim5_A.tab") + AvgChemShift_HA("2rsy.md.pdb_pred_D_sim1_B.tab","2rsy.md.pdb_pred_D_sim2_B.tab","2rsy.md.pdb_pred_D_sim3_B.tab","2rsy.md.pdb_pred_D_sim4_B.tab","2rsy.md.pdb_pred_D_sim5_B.tab")
Avg_HAShift_D_CMAP = AvgChemShift_HA("2rsy.md.pdb_pred_D_CMAP_sim1_A.tab","2rsy.md.pdb_pred_D_CMAP_sim2_A.tab","2rsy.md.pdb_pred_D_CMAP_sim3_A.tab","2rsy.md.pdb_pred_D_CMAP_sim4_A.tab","2rsy.md.pdb_pred_D_CMAP_sim5_A.tab") + AvgChemShift_HA("2rsy.md.pdb_pred_D_CMAP_sim1_B.tab","2rsy.md.pdb_pred_D_CMAP_sim2_B.tab","2rsy.md.pdb_pred_D_CMAP_sim3_B.tab","2rsy.md.pdb_pred_D_CMAP_sim4_B.tab","2rsy.md.pdb_pred_D_CMAP_sim5_B.tab")

print('ffptm EW HA ',RMSD(Avg_HAShift,ExpData_HA))
print('ff03CMAP EW HA ',RMSD(Avg_HAShift_CMAP,ExpData_HA))
print('ffptm D HA ',RMSD(Avg_HAShift_D,ExpData_HA))
print('ff03CMAP D HA ',RMSD(Avg_HAShift_D_CMAP,ExpData_HA))


# HN
Avg_HNShift = AvgChemShift_HN("2rsy.md.pdb_pred_sim1_A.tab","2rsy.md.pdb_pred_sim2_A.tab","2rsy.md.pdb_pred_sim3_A.tab","2rsy.md.pdb_pred_sim4_A.tab","2rsy.md.pdb_pred_sim5_A.tab") + AvgChemShift_HN("2rsy.md.pdb_pred_sim1_B.tab","2rsy.md.pdb_pred_sim2_B.tab","2rsy.md.pdb_pred_sim3_B.tab","2rsy.md.pdb_pred_sim4_B.tab","2rsy.md.pdb_pred_sim5_B.tab")
Avg_HNShift_CMAP = AvgChemShift_HN("2rsy.md.pdb_pred_CMAP_sim1_A.tab","2rsy.md.pdb_pred_CMAP_sim2_A.tab","2rsy.md.pdb_pred_CMAP_sim3_A.tab","2rsy.md.pdb_pred_CMAP_sim4_A.tab","2rsy.md.pdb_pred_CMAP_sim5_A.tab") + AvgChemShift_HN("2rsy.md.pdb_pred_CMAP_sim1_B.tab","2rsy.md.pdb_pred_CMAP_sim2_B.tab","2rsy.md.pdb_pred_CMAP_sim3_B.tab","2rsy.md.pdb_pred_CMAP_sim4_B.tab","2rsy.md.pdb_pred_CMAP_sim5_B.tab")
Avg_HNShift_D = AvgChemShift_HN("2rsy.md.pdb_pred_D_sim1_A.tab","2rsy.md.pdb_pred_D_sim2_A.tab","2rsy.md.pdb_pred_D_sim3_A.tab","2rsy.md.pdb_pred_D_sim4_A.tab","2rsy.md.pdb_pred_D_sim5_A.tab") + AvgChemShift_HN("2rsy.md.pdb_pred_D_sim1_B.tab","2rsy.md.pdb_pred_D_sim2_B.tab","2rsy.md.pdb_pred_D_sim3_B.tab","2rsy.md.pdb_pred_D_sim4_B.tab","2rsy.md.pdb_pred_D_sim5_B.tab")
Avg_HNShift_D_CMAP = AvgChemShift_HN("2rsy.md.pdb_pred_D_CMAP_sim1_A.tab","2rsy.md.pdb_pred_D_CMAP_sim2_A.tab","2rsy.md.pdb_pred_D_CMAP_sim3_A.tab","2rsy.md.pdb_pred_D_CMAP_sim4_A.tab","2rsy.md.pdb_pred_D_CMAP_sim5_A.tab") + AvgChemShift_HN("2rsy.md.pdb_pred_D_CMAP_sim1_B.tab","2rsy.md.pdb_pred_D_CMAP_sim2_B.tab","2rsy.md.pdb_pred_D_CMAP_sim3_B.tab","2rsy.md.pdb_pred_D_CMAP_sim4_B.tab","2rsy.md.pdb_pred_D_CMAP_sim5_B.tab")

print('ffptm EW HN ',RMSD(Avg_HNShift,ExpData_HN))
print('ff03CMAP EW HN ',RMSD(Avg_HNShift_CMAP,ExpData_HN))
print('ffptm D HN ',RMSD(Avg_HNShift_D,ExpData_HN))
print('ff03CMAP D HN ',RMSD(Avg_HNShift_D_CMAP,ExpData_HN))


# N
Avg_NShift = AvgChemShift_N("2rsy.md.pdb_pred_sim1_A.tab","2rsy.md.pdb_pred_sim2_A.tab","2rsy.md.pdb_pred_sim3_A.tab","2rsy.md.pdb_pred_sim4_A.tab","2rsy.md.pdb_pred_sim5_A.tab") + AvgChemShift_N("2rsy.md.pdb_pred_sim1_B.tab","2rsy.md.pdb_pred_sim2_B.tab","2rsy.md.pdb_pred_sim3_B.tab","2rsy.md.pdb_pred_sim4_B.tab","2rsy.md.pdb_pred_sim5_B.tab")
Avg_NShift_CMAP = AvgChemShift_N("2rsy.md.pdb_pred_CMAP_sim1_A.tab","2rsy.md.pdb_pred_CMAP_sim2_A.tab","2rsy.md.pdb_pred_CMAP_sim3_A.tab","2rsy.md.pdb_pred_CMAP_sim4_A.tab","2rsy.md.pdb_pred_CMAP_sim5_A.tab") + AvgChemShift_N("2rsy.md.pdb_pred_CMAP_sim1_B.tab","2rsy.md.pdb_pred_CMAP_sim2_B.tab","2rsy.md.pdb_pred_CMAP_sim3_B.tab","2rsy.md.pdb_pred_CMAP_sim4_B.tab","2rsy.md.pdb_pred_CMAP_sim5_B.tab")
Avg_NShift_D = AvgChemShift_N("2rsy.md.pdb_pred_D_sim1_A.tab","2rsy.md.pdb_pred_D_sim2_A.tab","2rsy.md.pdb_pred_D_sim3_A.tab","2rsy.md.pdb_pred_D_sim4_A.tab","2rsy.md.pdb_pred_D_sim5_A.tab") + AvgChemShift_N("2rsy.md.pdb_pred_D_sim1_B.tab","2rsy.md.pdb_pred_D_sim2_B.tab","2rsy.md.pdb_pred_D_sim3_B.tab","2rsy.md.pdb_pred_D_sim4_B.tab","2rsy.md.pdb_pred_D_sim5_B.tab")
Avg_NShift_D_CMAP = AvgChemShift_N("2rsy.md.pdb_pred_D_CMAP_sim1_A.tab","2rsy.md.pdb_pred_D_CMAP_sim2_A.tab","2rsy.md.pdb_pred_D_CMAP_sim3_A.tab","2rsy.md.pdb_pred_D_CMAP_sim4_A.tab","2rsy.md.pdb_pred_D_CMAP_sim5_A.tab") + AvgChemShift_N("2rsy.md.pdb_pred_D_CMAP_sim1_B.tab","2rsy.md.pdb_pred_D_CMAP_sim2_B.tab","2rsy.md.pdb_pred_D_CMAP_sim3_B.tab","2rsy.md.pdb_pred_D_CMAP_sim4_B.tab","2rsy.md.pdb_pred_D_CMAP_sim5_B.tab")

print('ffptm EW N ',RMSD(Avg_NShift,ExpData_N))
print('ff03CMAP EW N ',RMSD(Avg_NShift_CMAP,ExpData_N))
print('ffptm D N ',RMSD(Avg_NShift_D,ExpData_N))
print('ff03CMAP D N ',RMSD(Avg_NShift_D_CMAP,ExpData_N))
# Out:
# ffptm EW CA  1.095714054954833
# ff03CMAP EW CA  1.0817696220489692
# ffptm D CA  1.1830951959613252
# ff03CMAP D CA  1.118830495470152
# ffptm EW CB  2.41883936538902
# ff03CMAP EW CB  2.418499546649298
# ffptm D CB  2.429920915363428
# ff03CMAP D CB  2.506329887267342
# ffptm EW C  1.0494901575145916
# ff03CMAP EW C  1.0909471274447722
# ffptm D C  1.092792958103227
# ff03CMAP D C  1.1032112657872921
# ffptm EW HA  0
# ff03CMAP EW HA  0
# ffptm D HA  0
# ff03CMAP D HA  0
# ffptm EW HN  0.5626001222893575
# ff03CMAP EW HN  0.5911556670793237
# ffptm D HN  0.5545646849196223
# ff03CMAP D HN  0.5757419847119021
# ffptm EW N  2.8661945212982314
# ff03CMAP EW N  3.048358348173654
# ffptm D N  3.0241358499115076
# ff03CMAP D N  2.9573413877197208

# %%
RMSD_EW = (RMSD(Avg_CAShift,ExpData_CA),RMSD(Avg_CBShift,ExpData_CB),RMSD(Avg_CShift,ExpData_C),RMSD(Avg_HAShift,ExpData_HA),RMSD(Avg_HNShift,ExpData_HN),RMSD(Avg_NShift,ExpData_N))
RMSD_EWC = (RMSD(Avg_CAShift_CMAP,ExpData_CA),RMSD(Avg_CBShift_CMAP,ExpData_CB),RMSD(Avg_CShift_CMAP,ExpData_C),RMSD(Avg_HAShift_CMAP,ExpData_HA),RMSD(Avg_HNShift_CMAP,ExpData_HN),RMSD(Avg_NShift_CMAP,ExpData_N))
RMSD_D = (RMSD(Avg_CAShift_D,ExpData_CA),RMSD(Avg_CBShift_D,ExpData_CB),RMSD(Avg_CShift_D,ExpData_C),RMSD(Avg_HAShift_D,ExpData_HA),RMSD(Avg_HNShift_D,ExpData_HN),RMSD(Avg_NShift_D,ExpData_N))
RMSD_DC = (RMSD(Avg_CAShift_D_CMAP,ExpData_CA),RMSD(Avg_CBShift_D_CMAP,ExpData_CB),RMSD(Avg_CShift_D_CMAP,ExpData_C),RMSD(Avg_HAShift_D_CMAP,ExpData_HA),RMSD(Avg_HNShift_D_CMAP,ExpData_HN),RMSD(Avg_NShift_D_CMAP,ExpData_N))

# %%
ind = np.arange(len(RMSD_EW))  # the x locations for the groups
width = 0.15  # the width of the bars

fig, ax = plt.subplots(figsize=(8,3))
rects1 = ax.bar(ind - width*3/2, RMSD_EW, width, label='Forcefield PTM TIP4PEW')
rects2 = ax.bar(ind - width/2, RMSD_EWC, width, label='ff03CMAP TIP4PEW')
rects3 = ax.bar(ind + width/2, RMSD_D, width, label='Forcefield PTM TIP4PD')
rects4 = ax.bar(ind + width*3/2, RMSD_DC, width, label='ff03CMAP TIP4PD')                

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('RMSD')
ax.set_title('Chemical Shift of 2RSY')
ax.set_xticks(ind)
ax.set_xticklabels(('CA','CB','C','HA','HN','N'))
ax.legend()


plt.savefig('ChemShift_bar.png',dpi=100)

plt.show()

# %%
# Modified Residue
pSER_EW = (abs(Avg_CAShift[129]-ExpData_CA[129]),abs(Avg_CBShift[129]-ExpData_CB[129]),abs(Avg_CShift[129]-ExpData_C[129]),abs(Avg_HAShift[129]-ExpData_HA[129]),abs(Avg_HNShift[129]-ExpData_HN[129]),abs(Avg_NShift[129]-ExpData_N[129]))
pSER_EWC = (abs(Avg_CAShift_CMAP[129]-ExpData_CA[129]),abs(Avg_CBShift_CMAP[129]-ExpData_CB[129]),abs(Avg_CShift_CMAP[129]-ExpData_C[129]),abs(Avg_HAShift_CMAP[129]-ExpData_HA[129]),abs(Avg_HNShift_CMAP[129]-ExpData_HN[129]),abs(Avg_NShift_CMAP[129]-ExpData_N[129]))
pSER_D = (abs(Avg_CAShift_D[129]-ExpData_CA[129]),abs(Avg_CBShift_D[129]-ExpData_CB[129]),abs(Avg_CShift_D[129]-ExpData_C[129]),abs(Avg_HAShift_D[129]-ExpData_HA[129]),abs(Avg_HNShift_D[129]-ExpData_HN[129]),abs(Avg_NShift_D[129]-ExpData_N[129]))
pSER_DC = (abs(Avg_CAShift_D_CMAP[129]-ExpData_CA[129]),abs(Avg_CBShift_D_CMAP[129]-ExpData_CB[129]),abs(Avg_CShift_D_CMAP[129]-ExpData_C[129]),abs(Avg_HAShift_D_CMAP[129]-ExpData_HA[129]),abs(Avg_HNShift_D_CMAP[129]-ExpData_HN[129]),abs(Avg_NShift_D_CMAP[129]-ExpData_N[129]))


print(pSER_EW)
print(pSER_EWC)
print(pSER_D)
print(pSER_DC)
# Out:
# (0.9517999999999986, 2.069200000000002, 1.3466000000000236, 0.3583999999999996, 0.0973999999999986, 1.7195999999999998)
# (0.10440000000000538, 2.0220000000000056, 0.968199999999996, 0.1554000000000002, 0.10780000000000012, 1.9679999999999893)
# (0.3207999999999913, 2.127600000000001, 1.1898000000000195, 0.4177999999999997, 0.14599999999999902, 1.3467999999999876)
# (0.18739999999999668, 2.133800000000001, 0.470799999999997, 0.1756000000000002, 0.06880000000000042, 1.317200000000014)

# %%
ind = np.arange(len(pSER_EW))  # the x locations for the groups
width = 0.15  # the width of the bars

fig, ax = plt.subplots(figsize=(8,3))
rects1 = ax.bar(ind - width*3/2, pSER_EW, width, label='Forcefield PTM TIP4PEW')
rects2 = ax.bar(ind - width/2, pSER_EWC, width, label='ff03CMAP TIP4PEW')
rects3 = ax.bar(ind + width/2, pSER_D, width, label='Forcefield PTM TIP4PD')
rects4 = ax.bar(ind + width*3/2, pSER_DC, width, label='ff03CMAP TIP4PD')                

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('RMSD')
ax.set_title('Modified Site Chemical Shift of 2RSY')
ax.set_xticks(ind)
ax.set_xticklabels(('CA','CB','C','HA','HN','N'))
ax.legend()


plt.savefig('modifiedChemShift.png',dpi=300)

plt.show()
