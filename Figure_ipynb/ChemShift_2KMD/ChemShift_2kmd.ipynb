# %% [markdown]
# ## Make secondary chemical shift plot

# %%
# Import and defination

import matplotlib.pyplot as plt
import numpy as numpy
from ChemShift import *

# %%
# Test Block and Experiment Data

CAShift_sim1 = LoadPred_CA("2kmd.md.pdb_pred_sim1.tab")
CAShift2_sim1 = LoadPred_CA_2("2kmd.md.pdb_pred_sim1.tab")
CAShift_RC_sim1 = LoadPred_CA_RC("2kmd.md.pdb_pred_sim1.tab")


res_list = LoadPred_Res("2kmd.md.pdb_pred_sim1.tab")

ExpData_Raw = [56.05,55.603,56.785,58.287,52.588,54.392,59.972,63.02,54.953,54.74,59.912,63.392,58.229,59.035,57.607,57.612,56.811,56.835,59.881,57.62,54.01,56.727,58.542,54.034,64.645,58.451,61.662,46.779,59.246,65.856,59.071,57.749,59.148,58.114,59.551,54.3,46.859,59.272,62.721,58.778,49.569,61.84,58.64,54.854,55.475,60.615,59.665,66.477,58.89,67.27,60.126,57.69,61.572,66.853,59.265,62.373,54.942,66.519,55.829,58.492,56.578,58.4,54.155,55.188,45.883,63.666,51.844,61.659,58.304,57.562,58.007,59.116,54.441,57.856,47.512,55.355,54.704,58.272,62.927,52.226,56.891,44.182,60.447,60.576,62.206,61.831,57.336,57.68,55.77,48.957,62.441,56.139,61.944,65.371,47.973,57.986,64.419,57.913,60.132,58.933,57.362,57.721,59.612,64.872,57.138,57.434,56.933,56.898,54.23,62.349,57.555]

print(len(CAShift_sim1))
print(len(ExpData_Raw))

ExpData = [ExpData_Raw[i]-CAShift_RC_sim1[i] if ExpData_Raw[i] != None else None for i in range(len(CAShift_RC_sim1))]
# Out:
# 111
# 111

# %%
# Load 4 kinds of chemical shift data, all secondary chemical shift

CAShift2_sim1 = LoadPred_CA_2("2kmd.md.pdb_pred_sim1.tab")
CAShift2_sim2 = LoadPred_CA_2("2kmd.md.pdb_pred_sim2.tab")
CAShift2_sim3 = LoadPred_CA_2("2kmd.md.pdb_pred_sim3.tab")
CAShift2_sim4 = LoadPred_CA_2("2kmd.md.pdb_pred_sim4.tab")
CAShift2_sim5 = LoadPred_CA_2("2kmd.md.pdb_pred_sim5.tab")

AvgShift = [(CAShift2_sim1[i]+CAShift2_sim2[i]+CAShift2_sim3[i]+CAShift2_sim4[i]+CAShift2_sim5[i])/5 for i in range(len(CAShift2_sim1))]

CAShift2_CMAP_sim1 = LoadPred_CA_2("2kmd.md.pdb_pred_CMAP_sim1.tab")
CAShift2_CMAP_sim2 = LoadPred_CA_2("2kmd.md.pdb_pred_CMAP_sim2.tab")
CAShift2_CMAP_sim3 = LoadPred_CA_2("2kmd.md.pdb_pred_CMAP_sim3.tab")
CAShift2_CMAP_sim4 = LoadPred_CA_2("2kmd.md.pdb_pred_CMAP_sim4.tab")
CAShift2_CMAP_sim5 = LoadPred_CA_2("2kmd.md.pdb_pred_CMAP_sim5.tab")

AvgShift_CMAP = [(CAShift2_CMAP_sim1[i]+CAShift2_CMAP_sim2[i]+CAShift2_CMAP_sim3[i]+CAShift2_CMAP_sim4[i]+CAShift2_CMAP_sim5[i])/5 for i in range(len(CAShift2_CMAP_sim1))]

CAShift2_D_sim1 = LoadPred_CA_2("2kmd.md.pdb_pred_D_sim1.tab")
CAShift2_D_sim2 = LoadPred_CA_2("2kmd.md.pdb_pred_D_sim2.tab")
CAShift2_D_sim3 = LoadPred_CA_2("2kmd.md.pdb_pred_D_sim3.tab")
CAShift2_D_sim4 = LoadPred_CA_2("2kmd.md.pdb_pred_D_sim4.tab")
CAShift2_D_sim5 = LoadPred_CA_2("2kmd.md.pdb_pred_D_sim5.tab")

AvgShift_D = [(CAShift2_D_sim1[i]+CAShift2_D_sim2[i]+CAShift2_D_sim3[i]+CAShift2_D_sim4[i]+CAShift2_D_sim5[i])/5 for i in range(len(CAShift2_D_sim1))]

CAShift2_D_CMAP_sim1 = LoadPred_CA_2("2kmd.md.pdb_pred_D_CMAP_sim1.tab")
CAShift2_D_CMAP_sim2 = LoadPred_CA_2("2kmd.md.pdb_pred_D_CMAP_sim2.tab")
CAShift2_D_CMAP_sim3 = LoadPred_CA_2("2kmd.md.pdb_pred_D_CMAP_sim3.tab")
CAShift2_D_CMAP_sim4 = LoadPred_CA_2("2kmd.md.pdb_pred_D_CMAP_sim4.tab")
CAShift2_D_CMAP_sim5 = LoadPred_CA_2("2kmd.md.pdb_pred_D_CMAP_sim5.tab")

AvgShift_D_CMAP = [(CAShift2_D_CMAP_sim1[i]+CAShift2_D_CMAP_sim2[i]+CAShift2_D_CMAP_sim3[i]+CAShift2_D_CMAP_sim4[i]+CAShift2_D_CMAP_sim5[i])/5 for i in range(len(CAShift2_D_CMAP_sim1))]

# %%
# Plotting!

plt.subplots(figsize=(24,4))

plt.plot(AvgShift,'.-',label='ffptm TIP4Pew',color="tab:blue")
plt.plot(AvgShift_CMAP,'.-',label='ff03CMAP TIP4Pew',color="tab:orange")
plt.plot(AvgShift_D,'.-',label='ffptm TIP4PD',color="tab:green")
plt.plot(AvgShift_D_CMAP,'.-',label='ff03CMAP TIP4PD',color="tab:red")

plt.plot(ExpData,'.-',label='Experiment',color="black")



plt.title('Cα Chemical shift of 2KMD',loc='left')

plt.xlim(0, len(AvgShift)-1)
plt.xticks(np.arange(0,len(res_list)),res_list,rotation='60')

# Tag modified residues
plt.axvline(x=10, ymin=0, ymax=1,color="grey",linestyle="--")
plt.axvline(x=13, ymin=0, ymax=1,color="grey",linestyle="--")

plt.legend()
plt.savefig("ChemShift_2kmd.png",dpi=100)
plt.show()

# %%
# Plotting!

plt.subplots(figsize=(14,4))

plt.plot(AvgShift,'.-',label='ff03/TIP4PEw',color="tab:blue")
plt.plot(AvgShift_CMAP,'.-',label='ff03CMAP/TIP4PEw',color="tab:orange")
plt.plot(AvgShift_D,'.-',label='ff03/TIP4PD',color="tab:green")
plt.plot(AvgShift_D_CMAP,'.-',label='ff03CMAP/TIP4PD',color="tab:red")

plt.plot(ExpData,'.-',label='Experiment',color="black")


plt.xlim(7, 65-1)
plt.xticks(np.arange(7,len(res_list[0:65])),res_list[7:65],rotation='90',fontsize=11)

plt.ylim(-8.2,6.2)
plt.yticks(fontsize=12)
plt.ylabel("$\\rm{\\delta C \\alpha\\ (ppm)}$",fontsize=16)

# Tag modified residues
plt.axvline(x=10, ymin=0, ymax=1,color="grey",linestyle="--",label="modification site")
plt.axvline(x=13, ymin=0, ymax=1,color="grey",linestyle="--")

plt.legend(fontsize=14,ncol=3,loc='lower right')
plt.savefig("ChemShift_2kmd_figure.png",dpi=100)
plt.show()

# %%
print(RMSD(AvgShift,ExpData))
print(RMSD(AvgShift_CMAP,ExpData))
print(RMSD(AvgShift_D,ExpData))
print(RMSD(AvgShift_D_CMAP,ExpData))

plt.subplots(figsize=(4,3.5))

RMSD_1 = RMSD(AvgShift,ExpData)
RMSD_2 = RMSD(AvgShift_CMAP,ExpData)
RMSD_3 = RMSD(AvgShift_D,ExpData)
RMSD_4 = RMSD(AvgShift_D_CMAP,ExpData)

color=['tab:blue','tab:orange','tab:green','tab:red']
x_label=['PTM 4EW','CMAP 4EW','PTM 4D','CMAP 4D']
plt.xticks([1,3,5,7], x_label,rotation='30')#绘制x刻度标签
plt.bar([1,3,5,7], [RMSD_1,RMSD_2,RMSD_3,RMSD_4],color=color)

plt.tight_layout()

plt.savefig("2kmd_bar.png",dpi=100)
plt.show()
# Out:
# 1.0580002973019
# 0.9384381845288572
# 1.151351368530989
# 0.975672614428351

# %% [markdown]
# ## Make FF score

# %%
ExpData_CA = [56.05,55.603,56.785,58.287,52.588,54.392,59.972,63.02,54.953,54.74,59.912,63.392,58.229,59.035,57.607,57.612,56.811,56.835,59.881,57.62,54.01,56.727,58.542,54.034,64.645,58.451,61.662,46.779,59.246,65.856,59.071,57.749,59.148,58.114,59.551,54.3,46.859,59.272,62.721,58.778,49.569,61.84,58.64,54.854,55.475,60.615,59.665,66.477,58.89,67.27,60.126,57.69,61.572,66.853,59.265,62.373,54.942,66.519,55.829,58.492,56.578,58.4,54.155,55.188,45.883,63.666,51.844,61.659,58.304,57.562,58.007,59.116,54.441,57.856,47.512,55.355,54.704,58.272,62.927,52.226,56.891,44.182,60.447,60.576,62.206,61.831,57.336,57.68,55.77,48.957,62.441,56.139,61.944,65.371,47.973,57.986,64.419,57.913,60.132,58.933,57.362,57.721,59.612,64.872,57.138,57.434,56.933,56.898,54.23,62.349,57.555]
ExpData_CB = [29.665,32.991,30.079,28.2,19.505,41.133,32.82,32.144,42.394,42.755,73.21,32.341,64.213,65.454,32.737,29.889,32.464,32.493,63.386,28.733,18.606,42.045,32.546,18.62,69.313,38.541,63.035,None,37.653,68.437,32.162,29.583,28.624,28.32,31.541,43.306,None,39.706,32.896,32.72,42.462,30.035,28.708,29.071,31.037,71.69,29.366,68.371,31.142,32.83,29.441,40.537,27.954,31.096,32.445,27.423,17.957,31.712,39.031,28.557,38.464,61.054,41.807,34.484,None,31.363,41.018,38.383,28.271,32.223,39.218,25.51,35.239,64.81,None,17.758,18.515,43.859,27.251,19.141,43.605,None,33.098,28.603,27.203,39.882,41.093,29.697,41.641,20.166,32.541,40.399,37.651,32.151,None,40.833,38.212,41.323,29.383,28.998,32.729,40.861,29.49,38.295,42.328,31.414,33.107,30.351,41.197,32.629,33.724]
ExpData_C = [174.655,175.966,176.261,174.053,177.127,175.694,None,176.452,176.995,176.916,None,176.892,175.273,175.617,177.615,177.567,177.528,177.091,175.863,177.387,179.262,178.175,178.231,179.409,176.233,178.346,176.742,176.014,176.199,176.274,178.895,178.04,178.559,178.342,178.21,177.509,174.942,None,176.476,175.962,None,177.394,178.74,179.589,179.873,175.302,179.476,174.998,177.431,177.762,177.921,179.489,176.46,178.273,178.554,177.786,179.576,178.625,177.261,178.255,174.466,177.07,177.274,176.918,174.678,174.72,177.458,178.638,178.776,175.98,175.01,172.776,172.302,174.994,176.096,180.483,180.24,179.3,175.325,178.183,179.168,172.939,177.237,179.419,177.188,177.452,179.315,177.769,174.952,None,176.803,177.435,177.343,177.673,174.787,178.771,176.992,178.522,174.574,179.13,177.19,179.798,176.447,179.292,178.888,176.632,176.727,176.151,175.769,175.238,None]
ExpData_HA = [4.685,4.435,4.292,4.478,4.341,4.57,4.406,4.388,4.335,4.429,4.593,4.442,4.494,4.406,4.244,4.223,4.372,4.385,4.332,4.176,4.226,4.15,4.109,4.29,4.131,4.947,4.414,None,3.437,4.056,4.038,4.424,3.316,3.961,3.965,4.371,None,3.479,4.28,3.887,4.691,1.19,3.431,4.433,5.791,4.772,4.415,3.891,4.25,4.075,3.944,4.419,4.523,2.655,4.054,4.127,3.013,3.364,4.424,3.539,4.648,4.108,4.392,4.612,None,3.613,4.787,4.153,4.243,3.974,4.391,4.72,4.758,4.517,None,3.867,4.057,4.307,3.951,4.361,4.152,None,2.17,3.721,4.126,3.947,3.939,4.124,3.776,4.897,4.547,4.271,4.368,3.663,None,4.372,3.944,4.339,3.741,3.877,3.744,3.234,3.451,3.616,3.914,3.897,4.173,4.181,4.593,4.074,None]
ExpData_HN = [None,8.36,8.551,8.334,8.368,8.23,7.887,None,8.251,8.126,8.649,None,8.589,9.191,8.128,8.013,8.253,8.233,8.237,8.343,8.107,8.005,8.012,8.052,7.942,8.306,8.172,9.105,7.817,7.588,7.384,6.935,8.232,7.344,7.887,8.005,7.527,7.806,None,8.395,7.474,None,7.941,8.117,7.607,11.122,9.446,7.759,7.045,8.281,7.839,8.457,8.487,8.678,8.836,8.155,8.49,8.817,7.488,8.426,7.773,7.38,7.961,8.543,8.468,8.101,8.972,8.502,8.542,7.526,7.265,7.188,8.434,8.507,8.838,8.422,7.602,8.314,8.237,7.346,7.318,7.929,8.115,8.403,7.888,8.44,8.488,7.035,7.68,7.158,None,8.593,8.605,8.181,7.935,8.036,7.421,7.568,8.898,7.957,7.84,8.089,7.936,7.601,8.344,7.316,7.383,7.965,8.303,7.935,7.876]
ExpData_N = [None,121.781,122.316,119.969,126.345,119.495,121.031,None,122.734,123.659,119.848,None,117.174,119.524,122.35,120.914,120.006,120.448,116.295,121.467,123.308,120.041,119.442,122.532,114.833,119.136,117.279,110.672,121.382,114.232,119.404,122.157,118.321,116.092,120.934,114.447,110.578,121.55,None,122.331,115.763,None,116.087,116.952,120.756,121.743,118.686,116.616,123.042,116.419,119.347,119.31,124.4,119.57,117.626,121.567,123.468,117.695,115.941,122.355,112.425,114.927,116.675,122.928,108.283,120.706,128.337,123.783,118.455,116.893,113.639,119.75,123.62,112.777,107.927,122.989,121.225,120.827,112.565,119.69,119.25,105.777,121.337,114.971,116.735,122.463,116.551,114.984,117.938,117.411,None,122.772,119.129,120.487,104.054,119.204,119.558,117.633,118.855,116.652,118.331,118.911,118.399,120.719,120.281,114.148,119.405,121.275,121.511,120.435,130.276]

print(len(ExpData_CA),len(ExpData_CB),len(ExpData_C),len(ExpData_HA),len(ExpData_HN),len(ExpData_N))
# Out:
# 111 111 111 111 111 111

# %%
# CA
Avg_CAShift = AvgChemShift_CA("2kmd.md.pdb_pred_sim1.tab","2kmd.md.pdb_pred_sim2.tab","2kmd.md.pdb_pred_sim3.tab","2kmd.md.pdb_pred_sim4.tab","2kmd.md.pdb_pred_sim5.tab")
Avg_CAShift_CMAP = AvgChemShift_CA("2kmd.md.pdb_pred_CMAP_sim1.tab","2kmd.md.pdb_pred_CMAP_sim2.tab","2kmd.md.pdb_pred_CMAP_sim3.tab","2kmd.md.pdb_pred_CMAP_sim4.tab","2kmd.md.pdb_pred_CMAP_sim5.tab")
Avg_CAShift_D = AvgChemShift_CA("2kmd.md.pdb_pred_D_sim1.tab","2kmd.md.pdb_pred_D_sim2.tab","2kmd.md.pdb_pred_D_sim3.tab","2kmd.md.pdb_pred_D_sim4.tab","2kmd.md.pdb_pred_D_sim5.tab")
Avg_CAShift_D_CMAP = AvgChemShift_CA("2kmd.md.pdb_pred_D_CMAP_sim1.tab","2kmd.md.pdb_pred_D_CMAP_sim2.tab","2kmd.md.pdb_pred_D_CMAP_sim3.tab","2kmd.md.pdb_pred_D_CMAP_sim4.tab","2kmd.md.pdb_pred_D_CMAP_sim5.tab")

print('ffptm EW CA ',RMSD(Avg_CAShift,ExpData_CA))
print('ff03CMAP EW CA ',RMSD(Avg_CAShift_CMAP,ExpData_CA))
print('ffptm D CA ',RMSD(Avg_CAShift_D,ExpData_CA))
print('ff03CMAP D CA ',RMSD(Avg_CAShift_D_CMAP,ExpData_CA))


# CB
Avg_CBShift = AvgChemShift_CB("2kmd.md.pdb_pred_sim1.tab","2kmd.md.pdb_pred_sim2.tab","2kmd.md.pdb_pred_sim3.tab","2kmd.md.pdb_pred_sim4.tab","2kmd.md.pdb_pred_sim5.tab")
Avg_CBShift_CMAP = AvgChemShift_CB("2kmd.md.pdb_pred_CMAP_sim1.tab","2kmd.md.pdb_pred_CMAP_sim2.tab","2kmd.md.pdb_pred_CMAP_sim3.tab","2kmd.md.pdb_pred_CMAP_sim4.tab","2kmd.md.pdb_pred_CMAP_sim5.tab")
Avg_CBShift_D = AvgChemShift_CB("2kmd.md.pdb_pred_D_sim1.tab","2kmd.md.pdb_pred_D_sim2.tab","2kmd.md.pdb_pred_D_sim3.tab","2kmd.md.pdb_pred_D_sim4.tab","2kmd.md.pdb_pred_D_sim5.tab")
Avg_CBShift_D_CMAP = AvgChemShift_CB("2kmd.md.pdb_pred_D_CMAP_sim1.tab","2kmd.md.pdb_pred_D_CMAP_sim2.tab","2kmd.md.pdb_pred_D_CMAP_sim3.tab","2kmd.md.pdb_pred_D_CMAP_sim4.tab","2kmd.md.pdb_pred_D_CMAP_sim5.tab")

print('\nffptm EW CB ',RMSD(Avg_CBShift,ExpData_CB))
print('ff03CMAP EW CB ',RMSD(Avg_CBShift_CMAP,ExpData_CB))
print('ffptm D CB ',RMSD(Avg_CBShift_D,ExpData_CB))
print('ff03CMAP D CB ',RMSD(Avg_CBShift_D_CMAP,ExpData_CB))


# C
Avg_CShift = AvgChemShift_C("2kmd.md.pdb_pred_sim1.tab","2kmd.md.pdb_pred_sim2.tab","2kmd.md.pdb_pred_sim3.tab","2kmd.md.pdb_pred_sim4.tab","2kmd.md.pdb_pred_sim5.tab")
Avg_CShift_CMAP = AvgChemShift_C("2kmd.md.pdb_pred_CMAP_sim1.tab","2kmd.md.pdb_pred_CMAP_sim2.tab","2kmd.md.pdb_pred_CMAP_sim3.tab","2kmd.md.pdb_pred_CMAP_sim4.tab","2kmd.md.pdb_pred_CMAP_sim5.tab")
Avg_CShift_D = AvgChemShift_C("2kmd.md.pdb_pred_D_sim1.tab","2kmd.md.pdb_pred_D_sim2.tab","2kmd.md.pdb_pred_D_sim3.tab","2kmd.md.pdb_pred_D_sim4.tab","2kmd.md.pdb_pred_D_sim5.tab")
Avg_CShift_D_CMAP = AvgChemShift_C("2kmd.md.pdb_pred_D_CMAP_sim1.tab","2kmd.md.pdb_pred_D_CMAP_sim2.tab","2kmd.md.pdb_pred_D_CMAP_sim3.tab","2kmd.md.pdb_pred_D_CMAP_sim4.tab","2kmd.md.pdb_pred_D_CMAP_sim5.tab")

print('\nffptm EW C ',RMSD(Avg_CShift,ExpData_C))
print('ff03CMAP EW C ',RMSD(Avg_CShift_CMAP,ExpData_C))
print('ffptm D C ',RMSD(Avg_CShift_D,ExpData_C))
print('ff03CMAP D C ',RMSD(Avg_CShift_D_CMAP,ExpData_C))


# HA
Avg_HAShift = AvgChemShift_HA("2kmd.md.pdb_pred_sim1.tab","2kmd.md.pdb_pred_sim2.tab","2kmd.md.pdb_pred_sim3.tab","2kmd.md.pdb_pred_sim4.tab","2kmd.md.pdb_pred_sim5.tab")
Avg_HAShift_CMAP = AvgChemShift_HA("2kmd.md.pdb_pred_CMAP_sim1.tab","2kmd.md.pdb_pred_CMAP_sim2.tab","2kmd.md.pdb_pred_CMAP_sim3.tab","2kmd.md.pdb_pred_CMAP_sim4.tab","2kmd.md.pdb_pred_CMAP_sim5.tab")
Avg_HAShift_D = AvgChemShift_HA("2kmd.md.pdb_pred_D_sim1.tab","2kmd.md.pdb_pred_D_sim2.tab","2kmd.md.pdb_pred_D_sim3.tab","2kmd.md.pdb_pred_D_sim4.tab","2kmd.md.pdb_pred_D_sim5.tab")
Avg_HAShift_D_CMAP = AvgChemShift_HA("2kmd.md.pdb_pred_D_CMAP_sim1.tab","2kmd.md.pdb_pred_D_CMAP_sim2.tab","2kmd.md.pdb_pred_D_CMAP_sim3.tab","2kmd.md.pdb_pred_D_CMAP_sim4.tab","2kmd.md.pdb_pred_D_CMAP_sim5.tab")

print('\nffptm EW HA ',RMSD(Avg_HAShift,ExpData_HA))
print('ff03CMAP EW HA ',RMSD(Avg_HAShift_CMAP,ExpData_HA))
print('ffptm D HA ',RMSD(Avg_HAShift_D,ExpData_HA))
print('ff03CMAP D HA ',RMSD(Avg_HAShift_D_CMAP,ExpData_HA))


# HN
Avg_HNShift = AvgChemShift_HN("2kmd.md.pdb_pred_sim1.tab","2kmd.md.pdb_pred_sim2.tab","2kmd.md.pdb_pred_sim3.tab","2kmd.md.pdb_pred_sim4.tab","2kmd.md.pdb_pred_sim5.tab")
Avg_HNShift_CMAP = AvgChemShift_HN("2kmd.md.pdb_pred_CMAP_sim1.tab","2kmd.md.pdb_pred_CMAP_sim2.tab","2kmd.md.pdb_pred_CMAP_sim3.tab","2kmd.md.pdb_pred_CMAP_sim4.tab","2kmd.md.pdb_pred_CMAP_sim5.tab")
Avg_HNShift_D = AvgChemShift_HN("2kmd.md.pdb_pred_D_sim1.tab","2kmd.md.pdb_pred_D_sim2.tab","2kmd.md.pdb_pred_D_sim3.tab","2kmd.md.pdb_pred_D_sim4.tab","2kmd.md.pdb_pred_D_sim5.tab")
Avg_HNShift_D_CMAP = AvgChemShift_HN("2kmd.md.pdb_pred_D_CMAP_sim1.tab","2kmd.md.pdb_pred_D_CMAP_sim2.tab","2kmd.md.pdb_pred_D_CMAP_sim3.tab","2kmd.md.pdb_pred_D_CMAP_sim4.tab","2kmd.md.pdb_pred_D_CMAP_sim5.tab")

print('\nffptm EW HN ',RMSD(Avg_HNShift,ExpData_HN))
print('ff03CMAP EW HN ',RMSD(Avg_HNShift_CMAP,ExpData_HN))
print('ffptm D HN ',RMSD(Avg_HNShift_D,ExpData_HN))
print('ff03CMAP D HN ',RMSD(Avg_HNShift_D_CMAP,ExpData_HN))


# N
Avg_NShift = AvgChemShift_N("2kmd.md.pdb_pred_sim1.tab","2kmd.md.pdb_pred_sim2.tab","2kmd.md.pdb_pred_sim3.tab","2kmd.md.pdb_pred_sim4.tab","2kmd.md.pdb_pred_sim5.tab")
Avg_NShift_CMAP = AvgChemShift_N("2kmd.md.pdb_pred_CMAP_sim1.tab","2kmd.md.pdb_pred_CMAP_sim2.tab","2kmd.md.pdb_pred_CMAP_sim3.tab","2kmd.md.pdb_pred_CMAP_sim4.tab","2kmd.md.pdb_pred_CMAP_sim5.tab")
Avg_NShift_D = AvgChemShift_N("2kmd.md.pdb_pred_D_sim1.tab","2kmd.md.pdb_pred_D_sim2.tab","2kmd.md.pdb_pred_D_sim3.tab","2kmd.md.pdb_pred_D_sim4.tab","2kmd.md.pdb_pred_D_sim5.tab")
Avg_NShift_D_CMAP = AvgChemShift_N("2kmd.md.pdb_pred_D_CMAP_sim1.tab","2kmd.md.pdb_pred_D_CMAP_sim2.tab","2kmd.md.pdb_pred_D_CMAP_sim3.tab","2kmd.md.pdb_pred_D_CMAP_sim4.tab","2kmd.md.pdb_pred_D_CMAP_sim5.tab")

print('\nffptm EW N ',RMSD(Avg_NShift,ExpData_N))
print('ff03CMAP EW N ',RMSD(Avg_NShift_CMAP,ExpData_N))
print('ffptm D N ',RMSD(Avg_NShift_D,ExpData_N))
print('ff03CMAP D N ',RMSD(Avg_NShift_D_CMAP,ExpData_N))
# Out:
# ffptm EW CA  1.0441814333812791
# ff03CMAP EW CA  0.9328273707585781
# ffptm D CA  1.159575400974622
# ff03CMAP D CA  0.9644187804061041
#
# ffptm EW CB  1.001227187198098
# ff03CMAP EW CB  0.9439633597843643
# ffptm D CB  1.0956176421052681
# ff03CMAP D CB  0.9720713518445663
#
# ffptm EW C  1.141669694038391
# ff03CMAP EW C  1.091216593750382
# ffptm D C  1.1252489542953856
# ff03CMAP D C  1.1300697997827165
#
# ffptm EW HA  0.28826108158030306
# ff03CMAP EW HA  0.2764967192739016
# ffptm D HA  0.2822247876591118
# ff03CMAP D HA  0.3029169669169322
#
# ffptm EW HN  0.4808391279035814
# ff03CMAP EW HN  0.48015197113478086
# ffptm D HN  0.4863957509461422
# ff03CMAP D HN  0.5040010210612367
#
# ffptm EW N  2.4010896735408727
# ff03CMAP EW N  2.1503072700824006
# ffptm D N  2.387078217354686
# ff03CMAP D N  2.397171306737619

# %%
# Modified Residue
RMSD_EW = (RMSD(Avg_CAShift,ExpData_CA),RMSD(Avg_CBShift,ExpData_CB),RMSD(Avg_CShift,ExpData_C),RMSD(Avg_HAShift,ExpData_HA),RMSD(Avg_HNShift,ExpData_HN),RMSD(Avg_NShift,ExpData_N))
RMSD_EWC = (RMSD(Avg_CAShift_CMAP,ExpData_CA),RMSD(Avg_CBShift_CMAP,ExpData_CB),RMSD(Avg_CShift_CMAP,ExpData_C),RMSD(Avg_HAShift_CMAP,ExpData_HA),RMSD(Avg_HNShift_CMAP,ExpData_HN),RMSD(Avg_NShift_CMAP,ExpData_N))
RMSD_D = (RMSD(Avg_CAShift_D,ExpData_CA),RMSD(Avg_CBShift_D,ExpData_CB),RMSD(Avg_CShift_D,ExpData_C),RMSD(Avg_HAShift_D,ExpData_HA),RMSD(Avg_HNShift_D,ExpData_HN),RMSD(Avg_NShift_D,ExpData_N))
RMSD_DC = (RMSD(Avg_CAShift_D_CMAP,ExpData_CA),RMSD(Avg_CBShift_D_CMAP,ExpData_CB),RMSD(Avg_CShift_D_CMAP,ExpData_C),RMSD(Avg_HAShift_D_CMAP,ExpData_HA),RMSD(Avg_HNShift_D_CMAP,ExpData_HN),RMSD(Avg_NShift_D_CMAP,ExpData_N))

# %%
ind = np.arange(len(RMSD_EW))  # the x locations for the groups
width = 0.15  # the width of the bars

fig, ax = plt.subplots(figsize=(8,3))
rects1 = ax.bar(ind - width*3/2, RMSD_EW, width, label='Forcefield PTM TIP4PEW')
rects2 = ax.bar(ind - width/2, RMSD_EWC, width, label='ff03CMAP TIP4PEW')
rects3 = ax.bar(ind + width/2, RMSD_D, width, label='Forcefield PTM TIP4PD')
rects4 = ax.bar(ind + width*3/2, RMSD_DC, width, label='ff03CMAP TIP4PD')                

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('RMSD')
ax.set_title('Chemical Shift of 2KMD')
ax.set_xticks(ind)
ax.set_xticklabels(('CA','CB','C','HA','HN','N'))
ax.legend()


plt.savefig('ChemShift_bar.png',dpi=100)

plt.show()

# %%
# Modified Residue 1
pSER_EW = (abs(Avg_CAShift[10]-ExpData_CA[10]),abs(Avg_CBShift[10]-ExpData_CB[10]),abs(Avg_HAShift[10]-ExpData_HA[10]),abs(Avg_HNShift[10]-ExpData_HN[10]),abs(Avg_NShift[10]-ExpData_N[10]))
pSER_EWC = (abs(Avg_CAShift_CMAP[10]-ExpData_CA[10]),abs(Avg_CBShift_CMAP[10]-ExpData_CB[10]),abs(Avg_HAShift_CMAP[10]-ExpData_HA[10]),abs(Avg_HNShift_CMAP[10]-ExpData_HN[10]),abs(Avg_NShift_CMAP[10]-ExpData_N[10]))
pSER_D = (abs(Avg_CAShift_D[10]-ExpData_CA[10]),abs(Avg_CBShift_D[10]-ExpData_CB[10]),abs(Avg_HAShift_D[10]-ExpData_HA[10]),abs(Avg_HNShift_D[10]-ExpData_HN[10]),abs(Avg_NShift_D[10]-ExpData_N[10]))
pSER_DC = (abs(Avg_CAShift_D_CMAP[10]-ExpData_CA[10]),abs(Avg_CBShift_D_CMAP[10]-ExpData_CB[10]),abs(Avg_HAShift_D_CMAP[10]-ExpData_HA[10]),abs(Avg_HNShift_D_CMAP[10]-ExpData_HN[10]),abs(Avg_NShift_D_CMAP[10]-ExpData_N[10]))


print(pSER_EW)
print(pSER_EWC)
print(pSER_D)
print(pSER_DC)
# Out:
# (0.2816000000000045, 3.712399999999988, 0.02740000000000098, 0.7969999999999997, 6.982600000000005)
# (0.6577999999999875, 4.467200000000005, 0.08260000000000023, 0.5063999999999993, 3.243000000000009)
# (1.1572000000000031, 4.349399999999989, 0.11340000000000039, 0.5245999999999995, 2.7383999999999986)
# (0.8023999999999987, 4.509599999999992, 0.050799999999999734, 0.3658000000000001, 0.03860000000000241)

# %%
ind = np.arange(len(pSER_EW))  # the x locations for the groups
width = 0.15  # the width of the bars

fig, ax = plt.subplots(figsize=(8,3))
rects1 = ax.bar(ind - width*3/2, pSER_EW, width, label='Forcefield PTM TIP4PEW')
rects2 = ax.bar(ind - width/2, pSER_EWC, width, label='ff03CMAP TIP4PEW')
rects3 = ax.bar(ind + width/2, pSER_D, width, label='Forcefield PTM TIP4PD')
rects4 = ax.bar(ind + width*3/2, pSER_DC, width, label='ff03CMAP TIP4PD')                

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('RMSD')
ax.set_title('Modified Site 1 Chemical Shift of 2KMD')
ax.set_xticks(ind)
ax.set_xticklabels(('CA','CB','HA','HN','N'))
ax.legend()


plt.savefig('modified1ChemShift.png',dpi=100)

plt.show()

# %%
# Modified Residue 2
pSER_EW = (abs(Avg_CAShift[13]-ExpData_CA[13]),abs(Avg_CBShift[13]-ExpData_CB[13]),abs(Avg_CShift[13]-ExpData_C[13]),abs(Avg_HAShift[13]-ExpData_HA[13]),abs(Avg_HNShift[13]-ExpData_HN[13]),abs(Avg_NShift[13]-ExpData_N[13]))
pSER_EWC = (abs(Avg_CAShift_CMAP[13]-ExpData_CA[13]),abs(Avg_CBShift_CMAP[13]-ExpData_CB[13]),abs(Avg_CShift_CMAP[13]-ExpData_C[13]),abs(Avg_HAShift_CMAP[13]-ExpData_HA[13]),abs(Avg_HNShift_CMAP[13]-ExpData_HN[13]),abs(Avg_NShift_CMAP[13]-ExpData_N[13]))
pSER_D = (abs(Avg_CAShift_D[13]-ExpData_CA[13]),abs(Avg_CBShift_D[13]-ExpData_CB[13]),abs(Avg_CShift_D[13]-ExpData_C[13]),abs(Avg_HAShift_D[13]-ExpData_HA[13]),abs(Avg_HNShift_D[13]-ExpData_HN[13]),abs(Avg_NShift_D[13]-ExpData_N[13]))
pSER_DC = (abs(Avg_CAShift_D_CMAP[13]-ExpData_CA[13]),abs(Avg_CBShift_D_CMAP[13]-ExpData_CB[13]),abs(Avg_CShift_D_CMAP[13]-ExpData_C[13]),abs(Avg_HAShift_D_CMAP[13]-ExpData_HA[13]),abs(Avg_HNShift_D_CMAP[13]-ExpData_HN[13]),abs(Avg_NShift_D_CMAP[13]-ExpData_N[13]))


print(pSER_EW)
print(pSER_EWC)
print(pSER_D)
print(pSER_DC)
# Out:
# (0.4468000000000032, 1.6950000000000003, 0.28999999999999204, 0.09480000000000022, 0.3280000000000012, 0.6794000000000153)
# (1.5579999999999998, 2.3899999999999935, 0.48100000000002296, 0.10899999999999999, 0.39440000000000097, 0.5634000000000015)
# (0.6022000000000105, 2.698599999999999, 0.02019999999998845, 0.07040000000000024, 0.48220000000000063, 1.1463999999999999)
# (0.28180000000000405, 1.9209999999999994, 0.745599999999996, 0.05740000000000034, 0.7053999999999991, 0.8678000000000168)

# %%
ind = np.arange(len(pSER_EW))  # the x locations for the groups
width = 0.15  # the width of the bars

fig, ax = plt.subplots(figsize=(8,3))
rects1 = ax.bar(ind - width*3/2, pSER_EW, width, label='Forcefield PTM TIP4PEW')
rects2 = ax.bar(ind - width/2, pSER_EWC, width, label='ff03CMAP TIP4PEW')
rects3 = ax.bar(ind + width/2, pSER_D, width, label='Forcefield PTM TIP4PD')
rects4 = ax.bar(ind + width*3/2, pSER_DC, width, label='ff03CMAP TIP4PD')                

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('RMSD')
ax.set_title('Modified Site 2 Chemical Shift of 2KMD')
ax.set_xticks(ind)
ax.set_xticklabels(('CA','CB','C','HA','HN','N'))
ax.legend()


plt.savefig('modified2ChemShift.png',dpi=100)

plt.show()

# %%
# Modified Residues
Mod_RMSD_EW = (RMSD(Avg_CAShift[10:17:3],ExpData_CA[10:17:3]),RMSD(Avg_CBShift[10:17:3],ExpData_CB[10:17:3]),RMSD(Avg_HAShift[10:17:3],ExpData_HA[10:17:3]),RMSD(Avg_HNShift[10:17:3],ExpData_HN[10:17:3]),RMSD(Avg_NShift[10:17:3],ExpData_N[10:17:3]))
Mod_RMSD_EWC = (RMSD(Avg_CAShift_CMAP[10:17:3],ExpData_CA[10:17:3]),RMSD(Avg_CBShift_CMAP[10:17:3],ExpData_CB[10:17:3]),RMSD(Avg_HAShift_CMAP[10:17:3],ExpData_HA[10:17:3]),RMSD(Avg_HNShift_CMAP[10:17:3],ExpData_HN[10:17:3]),RMSD(Avg_NShift_CMAP[10:17:3],ExpData_N[10:17:3]))
Mod_RMSD_D = (RMSD(Avg_CAShift_D[10:17:3],ExpData_CA[10:17:3]),RMSD(Avg_CBShift_D[10:17:3],ExpData_CB[10:17:3]),RMSD(Avg_HAShift_D[10:17:3],ExpData_HA[10:17:3]),RMSD(Avg_HNShift_D[10:17:3],ExpData_HN[10:17:3]),RMSD(Avg_NShift_D[10:17:3],ExpData_N[10:17:3]))
Mod_RMSD_DC = (RMSD(Avg_CAShift_D_CMAP[10:17:3],ExpData_CA[10:17:3]),RMSD(Avg_CBShift_D_CMAP[10:17:3],ExpData_CB[10:17:3]),RMSD(Avg_HAShift_D_CMAP[10:17:3],ExpData_HA[10:17:3]),RMSD(Avg_HNShift_D_CMAP[10:17:3],ExpData_HN[10:17:3]),RMSD(Avg_NShift_D_CMAP[10:17:3],ExpData_N[10:17:3]))

print(Mod_RMSD_EW)
print(Mod_RMSD_EWC)
print(Mod_RMSD_D)
print(Mod_RMSD_DC)
# Out:
# (0.3734493272185702, 2.8857355006999437, 0.06977750353803185, 0.6094230878462025, 4.960760381231897)
# (1.1958396297162892, 3.5824555712527695, 0.096705118789028, 0.453867998431262, 2.3274952803389377)
# (0.9224306694814576, 3.619373034104104, 0.09438146004380342, 0.5038462066940665, 2.0991745425285617)
# (0.6013555520654982, 3.4660303778241706, 0.05420055350270886, 0.5618713375853938, 0.6142339945004792)

# %%
# Calculate Modified FF score

FF_score_list = [0,0,0,0]

for i in range(len(Mod_RMSD_EW)):
    min_RMSD = min(Mod_RMSD_EW[i],Mod_RMSD_EWC[i],Mod_RMSD_D[i],Mod_RMSD_DC[i])
    FF_score_list[0] += Mod_RMSD_EW[i]/min_RMSD
    FF_score_list[1] += Mod_RMSD_EWC[i]/min_RMSD
    FF_score_list[2] += Mod_RMSD_D[i]/min_RMSD
    FF_score_list[3] += Mod_RMSD_DC[i]/min_RMSD

FF_score_list = [i/len(Mod_RMSD_EW) for i in FF_score_list]

# %%
FF_score_list
# Out:
# [2.5412926189134746, 2.203411348745629, 1.9986520660956557, 1.2098652605785216]

# %%
ind = np.arange(len(Mod_RMSD_EW))  # the x locations for the groups
width = 0.2  # the width of the bars

plt.subplots(figsize=(18,4))

plt.subplot(1,2,1)

plt.bar(ind - width*3/2, Mod_RMSD_EW, width,edgecolor="k",linewidth="1.2", label='ff03/TIP4PEw')
plt.bar(ind - width/2, Mod_RMSD_EWC, width,edgecolor="k",linewidth="1.2", label='ff03CMAP/TIP4PEw')
plt.bar(ind + width/2, Mod_RMSD_D, width,edgecolor="k",linewidth="1.2", label='ff03/TIP4PD')
plt.bar(ind + width*3/2, Mod_RMSD_DC, width,edgecolor="k",linewidth="1.2", label='ff03CMAP/TIP4PD')                

for i in range(5):
    plt.text(x=(ind-width*3/2)[i],y=Mod_RMSD_EW[i]+0.2,s="%.2f"%Mod_RMSD_EW[i],ha="center",va="bottom",fontsize=14,rotation=90)
for i in range(5):
    plt.text(x=(ind-width/2)[i],y=Mod_RMSD_EWC[i]+0.2,s="%.2f"%Mod_RMSD_EWC[i],ha="center",va="bottom",fontsize=14,rotation=90)
for i in range(5):
    plt.text(x=(ind+width/2)[i],y=Mod_RMSD_D[i]+0.2,s="%.2f"%Mod_RMSD_D[i],ha="center",va="bottom",fontsize=14,rotation=90)
for i in range(5):
    plt.text(x=(ind+width*3/2)[i],y=Mod_RMSD_DC[i]+0.2,s="%.2f"%Mod_RMSD_DC[i],ha="center",va="bottom",fontsize=14,rotation=90)

# Add some text for labels, title and custom x-pltis tick labels, etc.
plt.ylabel('RMSD (ppm)',fontsize=14)
plt.ylim(0,9)
plt.yticks(fontsize=12)
plt.xticks(ind)
plt.xticks(np.arange(0,5),['CA','CB','HA','HN','N'],fontsize=14)
plt.legend(fontsize=13,loc="upper left")


plt.subplot(1,8,5)
for i in range(4):
    plt.bar(x=np.arange(0,2,0.3)[i],height=FF_score_list[i],width=0.3,edgecolor="k",linewidth="1.2")
    plt.text(x=np.arange(0,2,0.3)[i],y=FF_score_list[i]+0.1,s="%.2f"%FF_score_list[i],ha="center",va="bottom",fontsize=14,rotation=90)

plt.xlim(-0.4,1.3)
plt.ylim(0,4)
plt.xticks([])
plt.yticks(fontsize=12)
plt.ylabel('$\\rm{ModificationFF_{score}}$',fontsize=14)


plt.savefig('modifiedChemShift_total.png',dpi=100)

plt.show()
