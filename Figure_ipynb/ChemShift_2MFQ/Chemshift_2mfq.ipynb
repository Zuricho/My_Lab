# %%
import matplotlib.pyplot as plt
import numpy as numpy
from ChemShift import *

# %%
CAShift_RC_sim1_A = LoadPred_CA_RC("2mfq.md.pdb_pred_sim1_A.tab",29)
CAShift_RC_sim1_B = LoadPred_CA_RC("2mfq.md.pdb_pred_sim1_B.tab")


res_list = LoadPred_Res("2mfq.md.pdb_pred_sim1_A.tab",29) + LoadPred_Res("2mfq.md.pdb_pred_sim1_B.tab")

ExpData_Raw_A = [58.2,56.148,55.153,54.2,61.218,59.234,62.9,54.421,52.282,56.436,57.419,52.723,54.736,55.921,56.972,58.385,60.161,54.201,57.772,50.962,56.298,53.451,44.489,53.201,57.461,52.925,44.989,57.205,45.485,58.122,53.008,53.455,54.44,59.113,56.692,61.601,53.94,53.721,60.31,52.706,56.437,60.349,57.447,56.678,55.305,53.891,57.072,60.456,53.691,57.762,57.184,59.699,56.099,57.433,54.438,None,53.645,56.189,45.9,55.485,55.442,None,51.988,53.451,55.184,54.994,55.699,51.709,56.906,45,None,54.928,55.965,58.939,63.147,43.994,None,None,60.162,54.944,50.204,55.705,54.828,58.175,54.71,53.957,55.971,58.696,58.9,58.719,61.696,55.466,58.699,57.426,58.446,58.917,64.71,57.384,56.641,53.497,52.7,57.7,60.886,52.734,61.66,61.45,55.69,53.725,62.67,61.99,None,None,55.35,None,None]

ExpData_Raw_B = [43.97,62.96,53.58,50.697,60.917,59.5,56.9,None,55.19,62.47,54.63,57.9,61.8,57.931,58.26,55.15,49.236,64.15,55.94,59.45,57.34,None,None]

ExpData_A = [ExpData_Raw_A[i]-CAShift_RC_sim1_A[i] if ExpData_Raw_A[i] != None else None for i in range(len(ExpData_Raw_A))]
ExpData_B = [ExpData_Raw_B[i]-CAShift_RC_sim1_B[i] if ExpData_Raw_B[i] != None else None for i in range(len(ExpData_Raw_B))]

ExpData = ExpData_A + ExpData_B


print(len(CAShift_RC_sim1_A))
print(len(ExpData_Raw_A))

print(len(CAShift_RC_sim1_B))
print(len(ExpData_Raw_B))

print(len(ExpData))
# Out:
# 115
# 115
# 23
# 23
# 138

# %%
CAShift2_sim1 = LoadPred_CA_2("2mfq.md.pdb_pred_sim1_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_sim1_B.tab")
CAShift2_sim2 = LoadPred_CA_2("2mfq.md.pdb_pred_sim2_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_sim2_B.tab")
CAShift2_sim3 = LoadPred_CA_2("2mfq.md.pdb_pred_sim3_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_sim3_B.tab")
CAShift2_sim4 = LoadPred_CA_2("2mfq.md.pdb_pred_sim4_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_sim4_B.tab")
CAShift2_sim5 = LoadPred_CA_2("2mfq.md.pdb_pred_sim5_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_sim5_B.tab")

AvgShift_A = AvgChemShift_CA_2("2mfq.md.pdb_pred_sim1_A.tab","2mfq.md.pdb_pred_sim2_A.tab","2mfq.md.pdb_pred_sim3_A.tab","2mfq.md.pdb_pred_sim4_A.tab","2mfq.md.pdb_pred_sim5_A.tab",29)
AvgShift_B = AvgChemShift_CA_2("2mfq.md.pdb_pred_sim1_B.tab","2mfq.md.pdb_pred_sim2_B.tab","2mfq.md.pdb_pred_sim3_B.tab","2mfq.md.pdb_pred_sim4_B.tab","2mfq.md.pdb_pred_sim5_B.tab")
AvgShift = AvgShift_A + AvgShift_B


CAShift2_CMAP_sim1 = LoadPred_CA_2("2mfq.md.pdb_pred_CMAP_sim1_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_CMAP_sim1_B.tab")
CAShift2_CMAP_sim2 = LoadPred_CA_2("2mfq.md.pdb_pred_CMAP_sim2_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_CMAP_sim2_B.tab")
CAShift2_CMAP_sim3 = LoadPred_CA_2("2mfq.md.pdb_pred_CMAP_sim3_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_CMAP_sim3_B.tab")
CAShift2_CMAP_sim4 = LoadPred_CA_2("2mfq.md.pdb_pred_CMAP_sim4_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_CMAP_sim4_B.tab")
CAShift2_CMAP_sim5 = LoadPred_CA_2("2mfq.md.pdb_pred_CMAP_sim5_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_CMAP_sim5_B.tab")

AvgShift_A_CMAP = AvgChemShift_CA_2("2mfq.md.pdb_pred_CMAP_sim1_A.tab","2mfq.md.pdb_pred_CMAP_sim2_A.tab","2mfq.md.pdb_pred_CMAP_sim3_A.tab","2mfq.md.pdb_pred_CMAP_sim4_A.tab","2mfq.md.pdb_pred_CMAP_sim5_A.tab",29)
AvgShift_B_CMAP = AvgChemShift_CA_2("2mfq.md.pdb_pred_CMAP_sim1_B.tab","2mfq.md.pdb_pred_CMAP_sim2_B.tab","2mfq.md.pdb_pred_CMAP_sim3_B.tab","2mfq.md.pdb_pred_CMAP_sim4_B.tab","2mfq.md.pdb_pred_CMAP_sim5_B.tab")
AvgShift_CMAP = AvgShift_A_CMAP + AvgShift_B_CMAP


CAShift2_D_sim1 = LoadPred_CA_2("2mfq.md.pdb_pred_D_sim1_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_D_sim1_B.tab")
CAShift2_D_sim2 = LoadPred_CA_2("2mfq.md.pdb_pred_D_sim2_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_D_sim2_B.tab")
CAShift2_D_sim3 = LoadPred_CA_2("2mfq.md.pdb_pred_D_sim3_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_D_sim3_B.tab")
CAShift2_D_sim4 = LoadPred_CA_2("2mfq.md.pdb_pred_D_sim4_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_D_sim4_B.tab")
CAShift2_D_sim5 = LoadPred_CA_2("2mfq.md.pdb_pred_D_sim5_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_D_sim5_B.tab")

AvgShift_A_D = AvgChemShift_CA_2("2mfq.md.pdb_pred_D_sim1_A.tab","2mfq.md.pdb_pred_D_sim2_A.tab","2mfq.md.pdb_pred_D_sim3_A.tab","2mfq.md.pdb_pred_D_sim4_A.tab","2mfq.md.pdb_pred_D_sim5_A.tab",29)
AvgShift_B_D = AvgChemShift_CA_2("2mfq.md.pdb_pred_D_sim1_B.tab","2mfq.md.pdb_pred_D_sim2_B.tab","2mfq.md.pdb_pred_D_sim3_B.tab","2mfq.md.pdb_pred_D_sim4_B.tab","2mfq.md.pdb_pred_D_sim5_B.tab")
AvgShift_D = AvgShift_A_D + AvgShift_B_D


CAShift2_D_CMAP_sim1 = LoadPred_CA_2("2mfq.md.pdb_pred_D_CMAP_sim1_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_D_CMAP_sim1_B.tab")
CAShift2_D_CMAP_sim2 = LoadPred_CA_2("2mfq.md.pdb_pred_D_CMAP_sim2_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_D_CMAP_sim2_B.tab")
CAShift2_D_CMAP_sim3 = LoadPred_CA_2("2mfq.md.pdb_pred_D_CMAP_sim3_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_D_CMAP_sim3_B.tab")
CAShift2_D_CMAP_sim4 = LoadPred_CA_2("2mfq.md.pdb_pred_D_CMAP_sim4_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_D_CMAP_sim4_B.tab")
CAShift2_D_CMAP_sim5 = LoadPred_CA_2("2mfq.md.pdb_pred_D_CMAP_sim5_A.tab",29) + LoadPred_CA_2("2mfq.md.pdb_pred_D_CMAP_sim5_B.tab")

AvgShift_A_D_CMAP = AvgChemShift_CA_2("2mfq.md.pdb_pred_D_CMAP_sim1_A.tab","2mfq.md.pdb_pred_D_CMAP_sim2_A.tab","2mfq.md.pdb_pred_D_CMAP_sim3_A.tab","2mfq.md.pdb_pred_D_CMAP_sim4_A.tab","2mfq.md.pdb_pred_D_CMAP_sim5_A.tab",29)
AvgShift_B_D_CMAP = AvgChemShift_CA_2("2mfq.md.pdb_pred_D_CMAP_sim1_B.tab","2mfq.md.pdb_pred_D_CMAP_sim2_B.tab","2mfq.md.pdb_pred_D_CMAP_sim3_B.tab","2mfq.md.pdb_pred_D_CMAP_sim4_B.tab","2mfq.md.pdb_pred_D_CMAP_sim5_B.tab")
AvgShift_D_CMAP = AvgShift_A_D_CMAP + AvgShift_B_D_CMAP

# %%
# Plotting!

plt.subplots(figsize=(24,4))

plt.plot(AvgShift,'.-',label='ffptm TIP4Pew',color="tab:blue")
plt.plot(AvgShift_CMAP,'.-',label='ff03CMAP TIP4Pew',color="tab:orange")
plt.plot(AvgShift_D,'.-',label='ffptm TIP4PD',color="tab:green")
plt.plot(AvgShift_D_CMAP,'.-',label='ff03CMAP TIP4PD',color="tab:red")
plt.plot(ExpData,'.-',label='Experiment',color="black")



plt.title('Cα Chemical shift of 2MFQ',loc='left')

plt.xlim(0, len(AvgShift)-1)
plt.xticks(np.arange(0,len(res_list)),res_list,rotation='90')

# Tag modified residues
plt.axvline(x=134, ymin=0, ymax=1,color="grey",linestyle="--")

plt.legend()
plt.savefig("ChemShift_2mfq_1.png",dpi=300)
plt.show()

# %%
print(RMSD(AvgShift,ExpData))
print(RMSD(AvgShift_CMAP,ExpData))
print(RMSD(AvgShift_D,ExpData))
print(RMSD(AvgShift_D_CMAP,ExpData))
# Out:
# 1.1695277927844372
# 1.0660074558243084
# 1.166830897692345
# 1.0702746157019105
