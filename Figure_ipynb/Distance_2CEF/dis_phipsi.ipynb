# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

def loadfile(fileName):
    content = np.loadtxt(fileName,skiprows=1)
    return content

# %%
dihAngle_EW = loadfile("phipsi_EW.dat")
dihAngle_EW_CMAP = loadfile("phipsi_EW_CMAP.dat")

dihAngle_D = loadfile("phipsi_D.dat")
dihAngle_D_CMAP = loadfile("phipsi_D_CMAP.dat")



plt.subplots(figsize=(12,8))


plt.xticks()
plt.yticks([])

plt.subplot(221)
sns.kdeplot(dihAngle_EW[:,1],shade=True,cut=0,color="tab:blue")
sns.kdeplot(dihAngle_EW_CMAP[:,1],shade=True,cut=0,color="tab:orange")
plt.title("TIP4PEW phi")
plt.xticks()
plt.yticks([])
plt.xlim(-180,180)


plt.subplot(222)
sns.kdeplot(dihAngle_EW[:,2],shade=True,cut=0,color="tab:blue",label="forcefield PTM")
sns.kdeplot(dihAngle_EW_CMAP[:,2],shade=True,cut=0,color="tab:orange",label="ff03CMAP")
plt.title("TIP4PEW psi")
plt.xticks()
plt.yticks([])
plt.xlim(-180,180)
plt.legend()


plt.subplot(223)
sns.kdeplot(dihAngle_D[:,1],shade=True,cut=0,color="tab:green")
sns.kdeplot(dihAngle_D_CMAP[:,1],shade=True,cut=0,color="tab:red")
plt.title("TIP4PD phi")
plt.xticks()
plt.yticks([])
plt.xlim(-180,180)


plt.subplot(224)
sns.kdeplot(dihAngle_D[:,2],shade=True,cut=0,color="tab:green",label="forcefield PTM")
sns.kdeplot(dihAngle_D_CMAP[:,2],shade=True,cut=0,color="tab:red",label="ff03CMAP")
plt.title("TIP4PD psi")
plt.xticks()
plt.yticks([])
plt.xlim(-180,180)
plt.legend()



# sns.distplot(plotData)

plt.show()

# %%
plt.subplots(figsize=(12,8))


plt.xticks()
plt.yticks([])

plt.subplot(221)
sns.kdeplot(dihAngle_EW[:,3],shade=True,cut=0,color="tab:blue")
sns.kdeplot(dihAngle_EW_CMAP[:,3],shade=True,cut=0,color="tab:orange")
plt.title("TIP4PEW phi")
plt.xticks()
plt.yticks([])
plt.xlim(-180,180)


plt.subplot(222)
sns.kdeplot(dihAngle_EW[:,4],shade=True,cut=0,color="tab:blue",label="forcefield PTM")
sns.kdeplot(dihAngle_EW_CMAP[:,4],shade=True,cut=0,color="tab:orange",label="ff03CMAP")
plt.title("TIP4PEW psi")
plt.xticks()
plt.yticks([])
plt.xlim(-180,180)
plt.legend()


plt.subplot(223)
sns.kdeplot(dihAngle_D[:,3],shade=True,cut=0,color="tab:green")
sns.kdeplot(dihAngle_D_CMAP[:,3],shade=True,cut=0,color="tab:red")
plt.title("TIP4PD phi")
plt.xticks()
plt.yticks([])
plt.xlim(-180,180)


plt.subplot(224)
sns.kdeplot(dihAngle_D[:,4],shade=True,cut=0,color="tab:green",label="forcefield PTM")
sns.kdeplot(dihAngle_D_CMAP[:,4],shade=True,cut=0,color="tab:red",label="ff03CMAP")
plt.title("TIP4PD psi")
plt.xticks()
plt.yticks([])
plt.xlim(-180,180)
plt.legend()



# sns.distplot(plotData)

plt.show()

# %%
distance_EW = loadfile("distance_EW.dat")
distance_EW_CMAP = loadfile("distance_EW_CMAP.dat")

distance_D = loadfile("distance_D.dat")
distance_D_CMAP = loadfile("distance_D_CMAP.dat")



plt.subplots(figsize=(4, 2))

plt.xticks()
plt.yticks([])

sns.kdeplot(distance_D[:,1],shade=True,color="tab:green")

plt.xlim(0,)

# sns.distplot(plotData)

plt.show()
