# %%
import matplotlib.pyplot as plt
import numpy as numpy
from ChemShift import *

# %%
CAShift_sim1 = LoadPred_CA("2lje.md.pdb_pred_sim1.tab")
CAShift2_sim1 = LoadPred_CA_2("2lje.md.pdb_pred_sim1.tab")
CAShift_RC_sim1 = LoadPred_CA_RC("2lje.md.pdb_pred_sim1.tab")

CAShift2_CMAP_sim1 = LoadPred_CA_2("2lje.md.pdb_pred_CMAP_sim1.tab")



res_list = LoadPred_Res("2lje.md.pdb_pred_sim1.tab")

ExpData_Raw = [57.786,56.674,56.943,62.96,64.39,63.025,57.344,54.176,56.819,57.747,58.406,59.332,54.083,56.93,59.753,57.825,58.307,58.298,58.4,53.559,56.737,52.77,56.468,56.947,54.173,62.439,52.953,52.868,50.94,63.583,55.716,57.935,56.448,56.698,53.011,62.508,58.856,62.889,58.289,62.446,53.625,61.607,61.62,57.894,55.718,45.241,62.99]

print(len(CAShift_sim1))
print(len(ExpData_Raw))

ExpData = [ExpData_Raw[i]-CAShift_RC_sim1[i] for i in range(len(CAShift_RC_sim1))]
# Out:
# 47
# 47

# %%
CAShift2_sim1 = LoadPred_CA_2("2lje.md.pdb_pred_sim1.tab")
CAShift2_sim2 = LoadPred_CA_2("2lje.md.pdb_pred_sim2.tab")
CAShift2_sim3 = LoadPred_CA_2("2lje.md.pdb_pred_sim3.tab")
CAShift2_sim4 = LoadPred_CA_2("2lje.md.pdb_pred_sim4.tab")
CAShift2_sim5 = LoadPred_CA_2("2lje.md.pdb_pred_sim5.tab")

AvgShift = [(CAShift2_sim1[i]+CAShift2_sim2[i]+CAShift2_sim3[i]+CAShift2_sim4[i]+CAShift2_sim5[i])/5 for i in range(len(CAShift2_sim1))]

CAShift2_CMAP_sim1 = LoadPred_CA_2("2lje.md.pdb_pred_CMAP_sim1.tab")
CAShift2_CMAP_sim2 = LoadPred_CA_2("2lje.md.pdb_pred_CMAP_sim2.tab")
CAShift2_CMAP_sim3 = LoadPred_CA_2("2lje.md.pdb_pred_CMAP_sim3.tab")
CAShift2_CMAP_sim4 = LoadPred_CA_2("2lje.md.pdb_pred_CMAP_sim4.tab")
CAShift2_CMAP_sim5 = LoadPred_CA_2("2lje.md.pdb_pred_CMAP_sim5.tab")

AvgShift_CMAP = [(CAShift2_CMAP_sim1[i]+CAShift2_CMAP_sim2[i]+CAShift2_CMAP_sim3[i]+CAShift2_CMAP_sim4[i]+CAShift2_CMAP_sim5[i])/5 for i in range(len(CAShift2_CMAP_sim1))]

CAShift2_D_sim1 = LoadPred_CA_2("2lje.md.pdb_pred_D_sim1.tab")
CAShift2_D_sim2 = LoadPred_CA_2("2lje.md.pdb_pred_D_sim2.tab")
CAShift2_D_sim3 = LoadPred_CA_2("2lje.md.pdb_pred_D_sim3.tab")
CAShift2_D_sim4 = LoadPred_CA_2("2lje.md.pdb_pred_D_sim4.tab")
CAShift2_D_sim5 = LoadPred_CA_2("2lje.md.pdb_pred_D_sim5.tab")

AvgShift_D = [(CAShift2_D_sim1[i]+CAShift2_D_sim2[i]+CAShift2_D_sim3[i]+CAShift2_D_sim4[i]+CAShift2_D_sim5[i])/5 for i in range(len(CAShift2_D_sim1))]

CAShift2_D_CMAP_sim1 = LoadPred_CA_2("2lje.md.pdb_pred_D_CMAP_sim1.tab")
CAShift2_D_CMAP_sim2 = LoadPred_CA_2("2lje.md.pdb_pred_D_CMAP_sim2.tab")
CAShift2_D_CMAP_sim3 = LoadPred_CA_2("2lje.md.pdb_pred_D_CMAP_sim3.tab")
CAShift2_D_CMAP_sim4 = LoadPred_CA_2("2lje.md.pdb_pred_D_CMAP_sim4.tab")
CAShift2_D_CMAP_sim5 = LoadPred_CA_2("2lje.md.pdb_pred_D_CMAP_sim5.tab")

AvgShift_D_CMAP = [(CAShift2_D_CMAP_sim1[i]+CAShift2_D_CMAP_sim2[i]+CAShift2_D_CMAP_sim3[i]+CAShift2_D_CMAP_sim4[i]+CAShift2_D_CMAP_sim5[i])/5 for i in range(len(CAShift2_D_CMAP_sim1))]

# %%
print(RMSD(CAShift2_sim1,ExpData))
print(RMSD(CAShift2_CMAP_sim1,ExpData))

# print(RMSD(CAShift_sim1,ExpData_Raw))
# Out:
# 1.7381738793292827
# 1.6176022042839673

# %%
# Plotting!

plt.subplots(figsize=(10,4))

plt.plot(AvgShift,'.-',label='ffptm TIP4Pew',color="tab:blue")
plt.plot(AvgShift_CMAP,'.-',label='ff03CMAP TIP4Pew',color="tab:orange")
plt.plot(ExpData,'.-',label='Experiment',color="black")



plt.title('Cα Chemical shift of 2LJE',loc='left')

plt.xlim(0, len(AvgShift)-1)
plt.xticks(np.arange(0,len(res_list)),res_list,rotation='60')

# Tag modified residues
plt.axvline(x=31, ymin=0, ymax=1,color="grey",linestyle="--")
plt.axvline(x=43, ymin=0, ymax=1,color="grey",linestyle="--")

plt.legend()
plt.savefig("ChemShift_2lje_TIP4Pew.png",dpi=100)
plt.show()

# %%
print(RMSD(AvgShift,ExpData))
print(RMSD(AvgShift_CMAP,ExpData))
# Out:
# 1.2604907708818258
# 1.1714715769715345

# %%
# Plotting!

plt.subplots(figsize=(10,4))

plt.plot(AvgShift,'.-',label='ffptm TIP4Pew',color="tab:blue")
plt.plot(AvgShift_CMAP,'.-',label='ff03CMAP TIP4Pew',color="tab:orange")
plt.plot(AvgShift_D,'.-',label='ffptm TIP4PD',color="tab:green")
plt.plot(AvgShift_D_CMAP,'.-',label='ff03CMAP TIP4PD',color="tab:red")

plt.plot(ExpData,'.-',label='Experiment',color="black")



plt.title('Cα Chemical shift of 2LJE',loc='left')

plt.xlim(0, len(AvgShift)-1)
plt.xticks(np.arange(0,len(res_list)),res_list,rotation='60')

# Tag modified residues
plt.axvline(x=31, ymin=0, ymax=1,color="grey",linestyle="--")
plt.axvline(x=43, ymin=0, ymax=1,color="grey",linestyle="--")

plt.legend()
plt.savefig("ChemShift_2lje.png",dpi=100)
plt.show()

# %%
print(RMSD(AvgShift,ExpData))
print(RMSD(AvgShift_CMAP,ExpData))
print(RMSD(AvgShift_D,ExpData))
print(RMSD(AvgShift_D_CMAP,ExpData))
# Out:
# 1.2604907708818258
# 1.1714715769715345
# 0.9779970507646464
# 1.1350082202345495

# %%
# Test Plotting!

plt.subplots(figsize=(10,4))

plt.plot(CAShift2_D_CMAP_sim1,'.-',label='1')
plt.plot(CAShift2_D_CMAP_sim2,'.-',label='2')
plt.plot(CAShift2_D_CMAP_sim3,'.-',label='3')
plt.plot(CAShift2_D_CMAP_sim4,'.-',label='4')
plt.plot(CAShift2_D_CMAP_sim5,'.-',label='5')

plt.plot(ExpData,'.-',label='Experiment',color="black")



plt.title('Cα Chemical shift of 2LJE',loc='left')

plt.xlim(0, len(AvgShift)-1)
plt.xticks(np.arange(0,len(res_list)),res_list,rotation='60')

# Tag modified residues
plt.axvline(x=31, ymin=0, ymax=1,color="grey",linestyle="--")
plt.axvline(x=43, ymin=0, ymax=1,color="grey",linestyle="--")

plt.legend()
plt.show()

# %%
ExpData_CA = [57.786,56.674,56.943,62.96,64.39,63.025,57.344,54.176,56.819,57.747,58.406,59.332,54.083,56.93,59.753,57.825,58.307,58.298,58.4,53.559,56.737,52.77,56.468,56.947,54.173,62.439,52.953,52.868,50.94,63.583,55.716,57.935,56.448,56.698,53.011,62.508,58.856,62.889,58.289,62.446,53.625,61.607,61.62,57.894,55.718,45.241,62.99]
ExpData_CB = [30.045,41.853,41.735,38.219,69.052,38.104,29.375,41.5,32.703,32.19,29.34,39.16,18.409,30.515,39.01,29.349,29.388,29.447,32.17,18.561,30.573,18.747,32.526,29.521,40.971,69.255,18.949,38.995,38.798,31.888,41.683,38.424,32.831,29.784,19.021,69.6,63.705,69.292,39.222,69.403,38.852,38.526,69.517,38.782,30.827,None,70.61]
ExpData_C = [178.066,177.505,177.643,176.774,175.458,176.102,174.538,176.829,177.662,178.127,177.791,176.439,178.542,177.664,176.732,177.92,178.097,177.228,177.402,179.108,176.643,177.64,176.483,175.904,176.626,174.851,177.509,174.33,None,177.196,177.48,175.836,176.606,176.764,178.054,175.137,174.881,174.555,175.956,174.168,175.438,176.18,174.334,175.431,176.189,173.4,None]
ExpData_HA = [3.975,4.13,4.057,3.911,4.161,3.909,4.615,4.594,4.204,4.135,4.096,4.378,4.158,4.096,4.379,4.065,4.05,4.056,4.029,4.129,4.11,4.151,4.159,4.601,4.151,4.221,4.196,4.599,4.608,4.372,4.197,4.452,4.124,4.206,4.276,4.225,4.567,4.126,4.567,4.159,4.599,4.133,4.276,4.567,4.266,3.908,4.16]
ExpData_HN = [8.031,7.866,7.746,7.724,7.802,7.751,8.097,7.969,8.216,None,None,7.922,7.97,7.792,7.874,8.178,8.117,8.13,8.032,7.853,7.85,7.776,7.838,7.958,8.248,7.945,8.113,8.055,8.015,None,8.085,7.789,7.88,8.215,8.335,8.007,8.156,8.042,8.163,7.943,8.254,7.988,7.963,8.037,8.035,8.038,7.638]
ExpData_N = [119.867,120.1,118.481,116.207,114.581,119.805,118.76,117.884,121.014,None,None,118.859,122.111,117.588,119.916,119.398,120.386,119.473,118.929,121.514,117.944,122.381,118.327,120.598,121.214,113.708,124.543,116.039,119.625,None,119.443,119.182,121.752,121.14,124.506,111.925,117.676,116.343,120.983,114.474,120.598,119.988,115.445,122.379,122.859,109.795,118.473]

# %%
print(len(ExpData_CA),len(ExpData_CB),len(ExpData_C),len(ExpData_HA),len(ExpData_HN),len(ExpData_N))
# Out:
# 47 47 47 47 47 47

# %%
# CA
Avg_CAShift = AvgChemShift_CA("2lje.md.pdb_pred_sim1.tab","2lje.md.pdb_pred_sim2.tab","2lje.md.pdb_pred_sim3.tab","2lje.md.pdb_pred_sim4.tab","2lje.md.pdb_pred_sim5.tab")
Avg_CAShift_CMAP = AvgChemShift_CA("2lje.md.pdb_pred_CMAP_sim1.tab","2lje.md.pdb_pred_CMAP_sim2.tab","2lje.md.pdb_pred_CMAP_sim3.tab","2lje.md.pdb_pred_CMAP_sim4.tab","2lje.md.pdb_pred_CMAP_sim5.tab")
Avg_CAShift_D = AvgChemShift_CA("2lje.md.pdb_pred_D_sim1.tab","2lje.md.pdb_pred_D_sim2.tab","2lje.md.pdb_pred_D_sim3.tab","2lje.md.pdb_pred_D_sim4.tab","2lje.md.pdb_pred_D_sim5.tab")
Avg_CAShift_D_CMAP = AvgChemShift_CA("2lje.md.pdb_pred_D_CMAP_sim1.tab","2lje.md.pdb_pred_D_CMAP_sim2.tab","2lje.md.pdb_pred_D_CMAP_sim3.tab","2lje.md.pdb_pred_D_CMAP_sim4.tab","2lje.md.pdb_pred_D_CMAP_sim5.tab")

print('ffptm EW CA ',RMSD(Avg_CAShift,ExpData_CA))
print('ff03CMAP EW CA ',RMSD(Avg_CAShift_CMAP,ExpData_CA))
print('ffptm D CA ',RMSD(Avg_CAShift_D,ExpData_CA))
print('ff03CMAP D CA ',RMSD(Avg_CAShift_D_CMAP,ExpData_CA))

# CB
Avg_CBShift = AvgChemShift_CB("2lje.md.pdb_pred_sim1.tab","2lje.md.pdb_pred_sim2.tab","2lje.md.pdb_pred_sim3.tab","2lje.md.pdb_pred_sim4.tab","2lje.md.pdb_pred_sim5.tab")
Avg_CBShift_CMAP = AvgChemShift_CB("2lje.md.pdb_pred_CMAP_sim1.tab","2lje.md.pdb_pred_CMAP_sim2.tab","2lje.md.pdb_pred_CMAP_sim3.tab","2lje.md.pdb_pred_CMAP_sim4.tab","2lje.md.pdb_pred_CMAP_sim5.tab")
Avg_CBShift_D = AvgChemShift_CB("2lje.md.pdb_pred_D_sim1.tab","2lje.md.pdb_pred_D_sim2.tab","2lje.md.pdb_pred_D_sim3.tab","2lje.md.pdb_pred_D_sim4.tab","2lje.md.pdb_pred_D_sim5.tab")
Avg_CBShift_D_CMAP = AvgChemShift_CB("2lje.md.pdb_pred_D_CMAP_sim1.tab","2lje.md.pdb_pred_D_CMAP_sim2.tab","2lje.md.pdb_pred_D_CMAP_sim3.tab","2lje.md.pdb_pred_D_CMAP_sim4.tab","2lje.md.pdb_pred_D_CMAP_sim5.tab")

print('\nffptm EW CB ',RMSD(Avg_CBShift,ExpData_CB))
print('ff03CMAP EW CB ',RMSD(Avg_CBShift_CMAP,ExpData_CB))
print('ffptm D CB ',RMSD(Avg_CBShift_D,ExpData_CB))
print('ff03CMAP D CB ',RMSD(Avg_CBShift_D_CMAP,ExpData_CB))


# C
Avg_CShift = AvgChemShift_C("2lje.md.pdb_pred_sim1.tab","2lje.md.pdb_pred_sim2.tab","2lje.md.pdb_pred_sim3.tab","2lje.md.pdb_pred_sim4.tab","2lje.md.pdb_pred_sim5.tab")
Avg_CShift_CMAP = AvgChemShift_C("2lje.md.pdb_pred_CMAP_sim1.tab","2lje.md.pdb_pred_CMAP_sim2.tab","2lje.md.pdb_pred_CMAP_sim3.tab","2lje.md.pdb_pred_CMAP_sim4.tab","2lje.md.pdb_pred_CMAP_sim5.tab")
Avg_CShift_D = AvgChemShift_C("2lje.md.pdb_pred_D_sim1.tab","2lje.md.pdb_pred_D_sim2.tab","2lje.md.pdb_pred_D_sim3.tab","2lje.md.pdb_pred_D_sim4.tab","2lje.md.pdb_pred_D_sim5.tab")
Avg_CShift_D_CMAP = AvgChemShift_C("2lje.md.pdb_pred_D_CMAP_sim1.tab","2lje.md.pdb_pred_D_CMAP_sim2.tab","2lje.md.pdb_pred_D_CMAP_sim3.tab","2lje.md.pdb_pred_D_CMAP_sim4.tab","2lje.md.pdb_pred_D_CMAP_sim5.tab")

print('\nffptm EW C ',RMSD(Avg_CShift,ExpData_C))
print('ff03CMAP EW C ',RMSD(Avg_CShift_CMAP,ExpData_C))
print('ffptm D C ',RMSD(Avg_CShift_D,ExpData_C))
print('ff03CMAP D C ',RMSD(Avg_CShift_D_CMAP,ExpData_C))




# N
Avg_NShift = AvgChemShift_N("2lje.md.pdb_pred_sim1.tab","2lje.md.pdb_pred_sim2.tab","2lje.md.pdb_pred_sim3.tab","2lje.md.pdb_pred_sim4.tab","2lje.md.pdb_pred_sim5.tab")
Avg_NShift_CMAP = AvgChemShift_N("2lje.md.pdb_pred_CMAP_sim1.tab","2lje.md.pdb_pred_CMAP_sim2.tab","2lje.md.pdb_pred_CMAP_sim3.tab","2lje.md.pdb_pred_CMAP_sim4.tab","2lje.md.pdb_pred_CMAP_sim5.tab")
Avg_NShift_D = AvgChemShift_N("2lje.md.pdb_pred_D_sim1.tab","2lje.md.pdb_pred_D_sim2.tab","2lje.md.pdb_pred_D_sim3.tab","2lje.md.pdb_pred_D_sim4.tab","2lje.md.pdb_pred_D_sim5.tab")
Avg_NShift_D_CMAP = AvgChemShift_N("2lje.md.pdb_pred_D_CMAP_sim1.tab","2lje.md.pdb_pred_D_CMAP_sim2.tab","2lje.md.pdb_pred_D_CMAP_sim3.tab","2lje.md.pdb_pred_D_CMAP_sim4.tab","2lje.md.pdb_pred_D_CMAP_sim5.tab")

print('\nffptm EW N ',RMSD(Avg_NShift,ExpData_N))
print('ff03CMAP EW N ',RMSD(Avg_NShift_CMAP,ExpData_N))
print('ffptm D N ',RMSD(Avg_NShift_D,ExpData_N))
print('ff03CMAP D N ',RMSD(Avg_NShift_D_CMAP,ExpData_N))



# HA
Avg_HAShift = AvgChemShift_HA("2lje.md.pdb_pred_sim1.tab","2lje.md.pdb_pred_sim2.tab","2lje.md.pdb_pred_sim3.tab","2lje.md.pdb_pred_sim4.tab","2lje.md.pdb_pred_sim5.tab")
Avg_HAShift_CMAP = AvgChemShift_HA("2lje.md.pdb_pred_CMAP_sim1.tab","2lje.md.pdb_pred_CMAP_sim2.tab","2lje.md.pdb_pred_CMAP_sim3.tab","2lje.md.pdb_pred_CMAP_sim4.tab","2lje.md.pdb_pred_CMAP_sim5.tab")
Avg_HAShift_D = AvgChemShift_HA("2lje.md.pdb_pred_D_sim1.tab","2lje.md.pdb_pred_D_sim2.tab","2lje.md.pdb_pred_D_sim3.tab","2lje.md.pdb_pred_D_sim4.tab","2lje.md.pdb_pred_D_sim5.tab")
Avg_HAShift_D_CMAP = AvgChemShift_HA("2lje.md.pdb_pred_D_CMAP_sim1.tab","2lje.md.pdb_pred_D_CMAP_sim2.tab","2lje.md.pdb_pred_D_CMAP_sim3.tab","2lje.md.pdb_pred_D_CMAP_sim4.tab","2lje.md.pdb_pred_D_CMAP_sim5.tab")

print('\nffptm EW HA ',RMSD(Avg_HAShift,ExpData_HA))
print('ff03CMAP EW HA ',RMSD(Avg_HAShift_CMAP,ExpData_HA))
print('ffptm D HA ',RMSD(Avg_HAShift_D,ExpData_HA))
print('ff03CMAP D HA ',RMSD(Avg_HAShift_D_CMAP,ExpData_HA))


# HN
Avg_HNShift = AvgChemShift_HN("2lje.md.pdb_pred_sim1.tab","2lje.md.pdb_pred_sim2.tab","2lje.md.pdb_pred_sim3.tab","2lje.md.pdb_pred_sim4.tab","2lje.md.pdb_pred_sim5.tab")
Avg_HNShift_CMAP = AvgChemShift_HN("2lje.md.pdb_pred_CMAP_sim1.tab","2lje.md.pdb_pred_CMAP_sim2.tab","2lje.md.pdb_pred_CMAP_sim3.tab","2lje.md.pdb_pred_CMAP_sim4.tab","2lje.md.pdb_pred_CMAP_sim5.tab")
Avg_HNShift_D = AvgChemShift_HN("2lje.md.pdb_pred_D_sim1.tab","2lje.md.pdb_pred_D_sim2.tab","2lje.md.pdb_pred_D_sim3.tab","2lje.md.pdb_pred_D_sim4.tab","2lje.md.pdb_pred_D_sim5.tab")
Avg_HNShift_D_CMAP = AvgChemShift_HN("2lje.md.pdb_pred_D_CMAP_sim1.tab","2lje.md.pdb_pred_D_CMAP_sim2.tab","2lje.md.pdb_pred_D_CMAP_sim3.tab","2lje.md.pdb_pred_D_CMAP_sim4.tab","2lje.md.pdb_pred_D_CMAP_sim5.tab")

print('\nffptm EW HN ',RMSD(Avg_HNShift,ExpData_HN))
print('ff03CMAP EW HN ',RMSD(Avg_HNShift_CMAP,ExpData_HN))
print('ffptm D HN ',RMSD(Avg_HNShift_D,ExpData_HN))
print('ff03CMAP D HN ',RMSD(Avg_HNShift_D_CMAP,ExpData_HN))
# Out:
# ffptm EW CA  1.2352512238759183
# ff03CMAP EW CA  1.182256114016939
# ffptm D CA  0.9640677289936395
# ff03CMAP D CA  1.149655060933685
#
# ffptm EW CB  0.7704077535089241
# ff03CMAP EW CB  0.9484648297819654
# ffptm D CB  0.8156677237426738
# ff03CMAP D CB  0.9352872975128496
#
# ffptm EW C  0.7773165298355303
# ff03CMAP EW C  0.8511251063543233
# ffptm D C  0.6441037977082699
# ff03CMAP D C  0.9037093475719294
#
# ffptm EW N  1.5408969240271022
# ff03CMAP EW N  2.378707340232547
# ffptm D N  1.7576190437228272
# ff03CMAP D N  3.7278483547738994
#
# ffptm EW HA  0.1525344095178414
# ff03CMAP EW HA  0.22287714884720883
# ffptm D HA  0.14204504796779757
# ff03CMAP D HA  0.22247243502921007
#
# ffptm EW HN  0.26816706058155726
# ff03CMAP EW HN  0.2596613692228142
# ffptm D HN  0.25883763250346736
# ff03CMAP D HN  0.34095851583999115

# %%
# Modified Residue
RMSD_EW = (RMSD(Avg_CAShift,ExpData_CA),RMSD(Avg_CBShift,ExpData_CB),RMSD(Avg_CShift,ExpData_C),RMSD(Avg_NShift,ExpData_N),RMSD(Avg_HAShift,ExpData_HA),RMSD(Avg_HNShift,ExpData_HN))
RMSD_EWC = (RMSD(Avg_CAShift_CMAP,ExpData_CA),RMSD(Avg_CBShift_CMAP,ExpData_CB),RMSD(Avg_CShift_CMAP,ExpData_C),RMSD(Avg_NShift_CMAP,ExpData_N),RMSD(Avg_HAShift_CMAP,ExpData_HA),RMSD(Avg_HNShift_CMAP,ExpData_HN))
RMSD_D = (RMSD(Avg_CAShift_D,ExpData_CA),RMSD(Avg_CBShift_D,ExpData_CB),RMSD(Avg_CShift_D,ExpData_C),RMSD(Avg_NShift_D,ExpData_N),RMSD(Avg_HAShift_D,ExpData_HA),RMSD(Avg_HNShift_D,ExpData_HN))
RMSD_DC = (RMSD(Avg_CAShift_D_CMAP,ExpData_CA),RMSD(Avg_CBShift_D_CMAP,ExpData_CB),RMSD(Avg_CShift_D_CMAP,ExpData_C),RMSD(Avg_NShift_D_CMAP,ExpData_N),RMSD(Avg_HAShift_D_CMAP,ExpData_HA),RMSD(Avg_HNShift_D_CMAP,ExpData_HN))

# %%
ind = np.arange(len(RMSD_EW))  # the x locations for the groups
width = 0.15  # the width of the bars

fig, ax = plt.subplots(figsize=(8,3))
rects1 = ax.bar(ind - width*3/2, RMSD_EW, width, label='Forcefield PTM TIP4PEW')
rects2 = ax.bar(ind - width/2, RMSD_EWC, width, label='ff03CMAP TIP4PEW')
rects3 = ax.bar(ind + width/2, RMSD_D, width, label='Forcefield PTM TIP4PD')
rects4 = ax.bar(ind + width*3/2, RMSD_DC, width, label='ff03CMAP TIP4PD')                

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('RMSD')
ax.set_title('Chemical Shift of 2LJE')
ax.set_xticks(ind)
ax.set_xticklabels(('CA','CB','C','N','HA','HN'))
ax.legend()


plt.savefig('ChemShift_bar.png',dpi=100)

plt.show()

# %%
# Modified Residue
pTyr_EW = (abs(Avg_CAShift[31]-ExpData_CA[31]),abs(Avg_CBShift[31]-ExpData_CB[31]),abs(Avg_CShift[31]-ExpData_C[31]),abs(Avg_NShift[31]-ExpData_N[31]),abs(Avg_HAShift[31]-ExpData_HA[31]),abs(Avg_HNShift[31]-ExpData_HN[31]))
pTyr_EWC = (abs(Avg_CAShift_CMAP[31]-ExpData_CA[31]),abs(Avg_CBShift_CMAP[31]-ExpData_CB[31]),abs(Avg_CShift_CMAP[31]-ExpData_C[31]),abs(Avg_NShift_CMAP[31]-ExpData_N[31]),abs(Avg_HAShift_CMAP[31]-ExpData_HA[31]),abs(Avg_HNShift_CMAP[31]-ExpData_HN[31]))
pTyr_D = (abs(Avg_CAShift_D[31]-ExpData_CA[31]),abs(Avg_CBShift_D[31]-ExpData_CB[31]),abs(Avg_CShift_D[31]-ExpData_C[31]),abs(Avg_NShift_D[31]-ExpData_N[31]),abs(Avg_HAShift_D[31]-ExpData_HA[31]),abs(Avg_HNShift_D[31]-ExpData_HN[31]))
pTyr_DC = (abs(Avg_CAShift_D_CMAP[31]-ExpData_CA[31]),abs(Avg_CBShift_D_CMAP[31]-ExpData_CB[31]),abs(Avg_CShift_D_CMAP[31]-ExpData_C[31]),abs(Avg_NShift_D_CMAP[31]-ExpData_N[31]),abs(Avg_HAShift_D_CMAP[31]-ExpData_HA[31]),abs(Avg_HNShift_D_CMAP[31]-ExpData_HN[31]))

# %%
ind = np.arange(len(pTyr_EW))  # the x locations for the groups
width = 0.15  # the width of the bars

fig, ax = plt.subplots(figsize=(8,3))
rects1 = ax.bar(ind - width*3/2, pTyr_EW, width, label='Forcefield PTM TIP4PEW')
rects2 = ax.bar(ind - width/2, pTyr_EWC, width, label='ff03CMAP TIP4PEW')
rects3 = ax.bar(ind + width/2, pTyr_D, width, label='Forcefield PTM TIP4PD')
rects4 = ax.bar(ind + width*3/2, pTyr_DC, width, label='ff03CMAP TIP4PD')                

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('RMSD')
ax.set_title('Modified Site 1 Chemical Shift of 2LJE')
ax.set_xticks(ind)
ax.set_xticklabels(('CA','CB','C','N','HA','HN'))
ax.legend()


plt.savefig('modifiedChemShift1.png',dpi=100)

plt.show()

# %%
# Modified Residue
pTyr_EW = (abs(Avg_CAShift[43]-ExpData_CA[43]),abs(Avg_CBShift[43]-ExpData_CB[43]),abs(Avg_CShift[43]-ExpData_C[43]),abs(Avg_NShift[43]-ExpData_N[43]),abs(Avg_HAShift[43]-ExpData_HA[43]),abs(Avg_HNShift[43]-ExpData_HN[43]))
pTyr_EWC = (abs(Avg_CAShift_CMAP[43]-ExpData_CA[43]),abs(Avg_CBShift_CMAP[43]-ExpData_CB[43]),abs(Avg_CShift_CMAP[43]-ExpData_C[43]),abs(Avg_NShift_CMAP[43]-ExpData_N[43]),abs(Avg_HAShift_CMAP[43]-ExpData_HA[43]),abs(Avg_HNShift_CMAP[43]-ExpData_HN[43]))
pTyr_D = (abs(Avg_CAShift_D[43]-ExpData_CA[43]),abs(Avg_CBShift_D[43]-ExpData_CB[43]),abs(Avg_CShift_D[43]-ExpData_C[43]),abs(Avg_NShift_D[43]-ExpData_N[43]),abs(Avg_HAShift_D[43]-ExpData_HA[43]),abs(Avg_HNShift_D[43]-ExpData_HN[43]))
pTyr_DC = (abs(Avg_CAShift_D_CMAP[43]-ExpData_CA[43]),abs(Avg_CBShift_D_CMAP[43]-ExpData_CB[43]),abs(Avg_CShift_D_CMAP[43]-ExpData_C[43]),abs(Avg_NShift_D_CMAP[43]-ExpData_N[43]),abs(Avg_HAShift_D_CMAP[43]-ExpData_HA[43]),abs(Avg_HNShift_D_CMAP[43]-ExpData_HN[43]))

# %%
ind = np.arange(len(pTyr_EW))  # the x locations for the groups
width = 0.15  # the width of the bars

fig, ax = plt.subplots(figsize=(8,3))
rects1 = ax.bar(ind - width*3/2, pTyr_EW, width, label='Forcefield PTM TIP4PEW')
rects2 = ax.bar(ind - width/2, pTyr_EWC, width, label='ff03CMAP TIP4PEW')
rects3 = ax.bar(ind + width/2, pTyr_D, width, label='Forcefield PTM TIP4PD')
rects4 = ax.bar(ind + width*3/2, pTyr_DC, width, label='ff03CMAP TIP4PD')                

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('RMSD')
ax.set_title('Modified Site 2 Chemical Shift of 2LJE')
ax.set_xticks(ind)
ax.set_xticklabels(('CA','CB','C','N','HA','HN'))
ax.legend()


plt.savefig('modifiedChemShift2.png',dpi=100)

plt.show()
