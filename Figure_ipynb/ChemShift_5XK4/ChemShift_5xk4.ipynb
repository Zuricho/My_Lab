# %%
import matplotlib.pyplot as plt
import numpy as numpy
from ChemShift import *
from ChemShift import LoadPred_CA_RC

# %%
CAShift_RC_sim1 = LoadPred_CA_RC("5xk4.md.pdb_pred_sim1.tab")

res_list = LoadPred_Res("5xk4.md.pdb_pred_sim1.tab")



ExpData_Raw = [None,54.971,58.773,55.693,60.589,55.306,60.759,57.51,None,45.386,56.03,62.353,59.969,61.133,52.926,55.313,58.689,53.157,65.289,57.342,55.731,59.855,62.603,60.756,55.99,67.692,59.206,55.464,59.689,66.141,60.073,57.395,58.114,55.395,46.038,57.799,None,66.264,55.78,55.586,56.983,54.965,53.149,59.257,55.586,52.616,45.384,54.583,55.865,54.614,55.917,56.619,45.179,54.373,59.855,58.554,60.888,57.25,58.529,54.097,62.39,56.407,57.005,56.722,59.125,62.707,53.75,55.921,53.486,61.762,53.626,53.716,53.506,57.627,None,None]

ExpData = [ExpData_Raw[i]-CAShift_RC_sim1[i] if ExpData_Raw[i] != None else None for i in range(len(ExpData_Raw))]


print(len(ExpData_Raw))
# Out:
# 76

# %%
CAShift2_sim1 = LoadPred_CA_2("5xk4.md.pdb_pred_sim1.tab")
CAShift2_sim2 = LoadPred_CA_2("5xk4.md.pdb_pred_sim2.tab")
CAShift2_sim3 = LoadPred_CA_2("5xk4.md.pdb_pred_sim3.tab")
CAShift2_sim4 = LoadPred_CA_2("5xk4.md.pdb_pred_sim4.tab")
CAShift2_sim5 = LoadPred_CA_2("5xk4.md.pdb_pred_sim5.tab")


Avg_CAShift2 = AvgChemShift_CA_2("5xk4.md.pdb_pred_sim1.tab","5xk4.md.pdb_pred_sim2.tab","5xk4.md.pdb_pred_sim3.tab","5xk4.md.pdb_pred_sim4.tab","5xk4.md.pdb_pred_sim5.tab")

# %%
# Plotting!

plt.subplots(figsize=(16,4))

plt.plot(CAShift2_sim1,'.-',label='ffptm TIP4P 1')
plt.plot(CAShift2_sim2,'.-',label='ffptm TIP4P 2')
plt.plot(CAShift2_sim3,'.-',label='ffptm TIP4P 3')
plt.plot(CAShift2_sim4,'.-',label='ffptm TIP4P 4')
plt.plot(CAShift2_sim5,'.-',label='ffptm TIP4P 5')

plt.plot(ExpData,'.-',label='Experiment',color="black")



plt.title('Cα Chemical shift of 5XK4',loc='left')

plt.xlim(0, len(CAShift2_sim1)-1)
plt.xticks(np.arange(0,len(res_list)),res_list,rotation='60')

# Tag modified residues
plt.axvline(x=64, ymin=0, ymax=1,color="grey",linestyle="--")

plt.legend()
plt.show()

# %%
print(RMSD(CAShift2_sim1,ExpData))
print(RMSD(CAShift2_sim2,ExpData))

# print(RMSD(CAShift2_CMAP_sim1,ExpData))

# print(RMSD(CAShift_sim1,ExpData_Raw))
# Out:
# 1.2050044532674422
# 1.1400133987351972

# %%
# Plot Average

plt.subplots(figsize=(16,4))

plt.plot(Avg_CAShift2,'.-',label='ffptm TIP4P 1',color='tab:blue')

plt.plot(ExpData,'.-',label='Experiment',color="black")



plt.title('Cα Chemical shift of 5XK4',loc='left')

plt.xlim(0, len(CAShift2_sim1)-1)
plt.xticks(np.arange(0,len(res_list)),res_list,rotation='60')

# Tag modified residues
plt.axvline(x=64, ymin=0, ymax=1,color="grey",linestyle="--")

plt.legend()
plt.show()

# %%
print(RMSD(Avg_CAShift2,ExpData))
# Out:
# 0.9748390332998937

# %%
CAShift2_CMAP_sim1 = LoadPred_CA_2("5xk4.md.pdb_pred_CMAP_sim1.tab")
CAShift2_CMAP_sim2 = LoadPred_CA_2("5xk4.md.pdb_pred_CMAP_sim2.tab")
CAShift2_CMAP_sim3 = LoadPred_CA_2("5xk4.md.pdb_pred_CMAP_sim3.tab")
CAShift2_CMAP_sim4 = LoadPred_CA_2("5xk4.md.pdb_pred_CMAP_sim4.tab")
CAShift2_CMAP_sim5 = LoadPred_CA_2("5xk4.md.pdb_pred_CMAP_sim5.tab")

Avg_CAShift2_CMAP = AvgChemShift_CA_2("5xk4.md.pdb_pred_CMAP_sim1.tab","5xk4.md.pdb_pred_CMAP_sim2.tab","5xk4.md.pdb_pred_CMAP_sim3.tab","5xk4.md.pdb_pred_CMAP_sim4.tab","5xk4.md.pdb_pred_CMAP_sim5.tab")

# %%
# Plotting!

plt.subplots(figsize=(16,4))

plt.plot(CAShift2_CMAP_sim1,'.-',label='ff03CMAP TIP4P 1')
plt.plot(CAShift2_CMAP_sim2,'.-',label='ff03CMAP TIP4P 2')
plt.plot(CAShift2_CMAP_sim3,'.-',label='ff03CMAP TIP4P 3')
plt.plot(CAShift2_CMAP_sim4,'.-',label='ff03CMAP TIP4P 4')
plt.plot(CAShift2_CMAP_sim5,'.-',label='ff03CMAP TIP4P 5')

plt.plot(ExpData,'.-',label='Experiment',color="black")



plt.title('Cα Chemical shift of 5XK4',loc='left')

plt.xlim(0, len(CAShift2_CMAP_sim1)-1)
plt.xticks(np.arange(0,len(res_list)),res_list,rotation='60')

# Tag modified residues
plt.axvline(x=64, ymin=0, ymax=1,color="grey",linestyle="--")

plt.legend()
plt.show()

# %%
# Plot Average

plt.subplots(figsize=(16,4))

plt.plot(Avg_CAShift2,'.-',label='Forcefield PTM TIP4PEW',color='tab:blue')
plt.plot(Avg_CAShift2_CMAP,'.-',label='ff03CMAP TIP4PEW',color='tab:orange')

plt.plot(ExpData,'.-',label='Experiment',color="black")



plt.title('Cα Chemical shift of 5XK4',loc='left')

plt.xlim(0, len(CAShift2_sim1)-1)
plt.xticks(np.arange(0,len(res_list)),res_list,rotation='60')

# Tag modified residues
plt.axvline(x=64, ymin=0, ymax=1,color="grey",linestyle="--")

plt.legend()

plt.savefig("5xk4_TIP4PEW.png",dpi=100)
plt.show()

# %%
print(RMSD(Avg_CAShift2,ExpData))
print(RMSD(Avg_CAShift2_CMAP,ExpData))
# Out:
# 0.9748390332998937
# 0.9846744064717865

# %%
Avg_CAShift2_D = AvgChemShift_CA_2("5xk4.md.pdb_pred_D_sim1.tab","5xk4.md.pdb_pred_D_sim2.tab","5xk4.md.pdb_pred_D_sim3.tab","5xk4.md.pdb_pred_D_sim4.tab","5xk4.md.pdb_pred_D_sim5.tab")
Avg_CAShift2_D_CMAP = AvgChemShift_CA_2("5xk4.md.pdb_pred_D_CMAP_sim1.tab","5xk4.md.pdb_pred_D_CMAP_sim2.tab","5xk4.md.pdb_pred_D_CMAP_sim3.tab","5xk4.md.pdb_pred_D_CMAP_sim4.tab","5xk4.md.pdb_pred_D_CMAP_sim5.tab")

# Plot Average

plt.subplots(figsize=(16,4))

plt.plot(Avg_CAShift2_D,'.-',label='Forcefield PTM TIP4PD',color='tab:green')
plt.plot(Avg_CAShift2_D_CMAP,'.-',label='ff03CMAP TIP4PD',color='tab:red')

plt.plot(ExpData,'.-',label='Experiment',color="black")



plt.title('Cα Chemical shift of 5XK4',loc='left')

plt.xlim(0, len(CAShift2_sim1)-1)
plt.xticks(np.arange(0,len(res_list)),res_list,rotation='60')

# Tag modified residues
plt.axvline(x=64, ymin=0, ymax=1,color="grey",linestyle="--")

plt.legend()

plt.savefig("5xk4_TIP4PD.png",dpi=100)
plt.show()

# %%
print(RMSD(Avg_CAShift2_D,ExpData))
print(RMSD(Avg_CAShift2_D_CMAP,ExpData))
# Out:
# 0.9659506178145647
# 0.9097161609651265

# %%
# Plot Average

plt.subplots(figsize=(16,4))

plt.plot(Avg_CAShift2,'.-',label='Forcefield PTM TIP4PEW',color='tab:blue')
plt.plot(Avg_CAShift2_CMAP,'.-',label='ff03CMAP TIP4PEW',color='tab:orange')
plt.plot(Avg_CAShift2_D,'.-',label='Forcefield PTM TIP4PD',color='tab:green')
plt.plot(Avg_CAShift2_D_CMAP,'.-',label='ff03CMAP TIP4PD',color='tab:red')

plt.plot(ExpData,'.-',label='Experiment',color="black")



plt.title('Cα Chemical shift of 5XK4',loc='left')

plt.xlim(0, len(CAShift2_sim1)-1)
plt.xticks(np.arange(0,len(res_list)),res_list,rotation='60')

# Tag modified residues
plt.axvline(x=64, ymin=0, ymax=1,color="grey",linestyle="--")

plt.legend()

plt.savefig("5xk4_ChemShift.png",dpi=100)
plt.show()

# %%
plt.subplots(figsize=(4,3.5))

ExpData_CA = ExpData_Raw

Avg_CAShift = AvgChemShift_CA("5xk4.md.pdb_pred_sim1.tab","5xk4.md.pdb_pred_sim2.tab","5xk4.md.pdb_pred_sim3.tab","5xk4.md.pdb_pred_sim4.tab","5xk4.md.pdb_pred_sim5.tab")
Avg_CAShift_CMAP = AvgChemShift_CA("5xk4.md.pdb_pred_CMAP_sim1.tab","5xk4.md.pdb_pred_CMAP_sim2.tab","5xk4.md.pdb_pred_CMAP_sim3.tab","5xk4.md.pdb_pred_CMAP_sim4.tab","5xk4.md.pdb_pred_CMAP_sim5.tab")
Avg_CAShift_D = AvgChemShift_CA("5xk4.md.pdb_pred_D_sim1.tab","5xk4.md.pdb_pred_D_sim2.tab","5xk4.md.pdb_pred_D_sim3.tab","5xk4.md.pdb_pred_D_sim4.tab","5xk4.md.pdb_pred_D_sim5.tab")
Avg_CAShift_D_CMAP = AvgChemShift_CA("5xk4.md.pdb_pred_D_CMAP_sim1.tab","5xk4.md.pdb_pred_D_CMAP_sim2.tab","5xk4.md.pdb_pred_D_CMAP_sim3.tab","5xk4.md.pdb_pred_D_CMAP_sim4.tab","5xk4.md.pdb_pred_D_CMAP_sim5.tab")


RMSD_1 = RMSD(Avg_CAShift,ExpData_CA)
RMSD_2 = RMSD(Avg_CAShift_CMAP,ExpData_CA)
RMSD_3 = RMSD(Avg_CAShift_D,ExpData_CA)
RMSD_4 = RMSD(Avg_CAShift_D_CMAP,ExpData_CA)

color=['tab:blue','tab:orange','tab:green','tab:red']
x_label=['PTM TIP4PEW','CMAP TIP4PEW','PTM TIP4PD','CMAP TIP4PD']
plt.xticks([1,3,5,7], x_label,rotation='30')
plt.bar([1,3,5,7], [RMSD_1,RMSD_2,RMSD_3,RMSD_4],color=color)

plt.tight_layout()

plt.savefig("5xk4_bar.png",dpi=100)
plt.show()

# %%
print(RMSD(Avg_CAShift,ExpData_CA))
print(RMSD(Avg_CAShift_CMAP,ExpData_CA))
print(RMSD(Avg_CAShift_D,ExpData_CA))
print(RMSD(Avg_CAShift_D_CMAP,ExpData_CA))
# Out:
# 0.9639407345466376
# 0.9796698124411374
# 0.9594814852634629
# 0.9072437733185901

# %%
ExpData_CA = [None,54.971,58.773,55.693,60.589,55.306,60.759,57.51,None,45.386,56.03,62.353,59.969,61.133,52.926,55.313,58.689,53.157,65.289,57.342,55.731,59.855,62.603,60.756,55.99,67.692,59.206,55.464,59.689,66.141,60.073,57.395,58.114,55.395,46.038,57.799,None,66.264,55.78,55.586,56.983,54.965,53.149,59.257,55.586,52.616,45.384,54.583,55.865,54.614,55.917,56.619,45.179,54.373,59.855,58.554,60.888,57.25,58.529,54.097,62.39,56.407,57.005,56.722,59.125,62.707,53.75,55.921,53.486,61.762,53.626,53.716,53.506,57.627,None,None]

ExpData_C = [171.222,174.801,173.302,174.989,174.595,176.57,176.875,None,175.448,173.925,175.654,174.594,174.654,173.691,174.642,175.785,174.131,None,175.304,174.451,176.296,176.427,None,178.91,None,177.838,180.457,180.16,175.106,178.112,178.759,177.188,177.745,177.915,173.875,None,None,178.204,177.018,175.46,176.292,173.755,175.149,175.444,None,177.288,178.247,174.575,175.829,176.66,175.611,None,174.772,175.469,176.546,180.07,176.827,177.414,174.448,174.073,176.773,175.167,176.222,177.336,174.555,173.888,174.735,174.78,175.99,173.824,175.049,174.031,178.722,None,None,None]

ExpData_CB = [None,31.24,40.838,40.669,33.604,33.968,70.186,41.589,None,None,33.37,70.188,40.838,70.038,45.863,30.193,35.88,30.581,31.815,63.534,40.899,71.283,34.673,28.744,38.335,30.798,33.761,17.658,33.252,36.712,27.604,41.077,33.933,33.333,None,40.497,None,32.916,39.796,30.037,31.2,31.607,44.774,39.656,42.742,16.396,None,34.439,29.193,41.553,31.976,40.604,None,32.574,72.217,40.88,62.848,40.533,39.83,37.389,37.645,28.541,30.656,30.798,65.78,71.42,44.83,31.842,46.046,34.835,44.329,33.356,43.226,30.954,None,None]

ExpData_N = [None,123.656,116.941,122.544,123.61,128.73,115.625,120.522,None,109.457,121.518,120.274,126.521,120.216,124.719,122.781,117.548,120.404,None,104.392,123.782,109.36,121.225,None,121.433,122.241,118.803,123.595,120.032,121.126,123.692,119.83,115.593,114.42,109.042,120.436,None,None,113.713,116.852,118.012,123.053,124.567,123.56,127.584,None,102.587,122.307,123.617,126.249,122.886,120.817,None,119.401,109.771,119.742,112.611,122.19,115.801,116.04,119.534,119.129,117.682,119.904,117.415,115.129,126.551,122.518,122.337,122.162,127.364,126.549,120.582,None,None,None]

ExpData_HA = [5.066,4.718,5.2,4.608,5.167,4.788,4.858,None,None,None,4.367,5.169,4.545,4.961,4.715,4.904,4.665,4.932,4.13,4.116,4.681,4.842,None,3.859,4.528,3.351,4.555,4.131,4.158,3.473,3.784,4.286,4.294,4.546,None,4.413,None,4.082,4.389,4.345,4.126,4.452,5.151,4.754,5.083,3.724,None,4.587,4.564,4.05,4.48,None,None,4.707,5.14,4.053,4.212,4.246,4.572,4.302,3.916,4.33,3.967,4.399,4.454,5.348,4.693,5.358,5.225,4.597,5.089,4.615,4.154,5.146,None,None]

ExpData_HN = [None,8.607,8.506,8.476,9.339,8.824,8.748,8.959,None,7.853,7.239,8.673,9.359,8.585,8.698,8.252,8.569,8.688,None,7.12,7.987,8.027,8.484,None,7.952,8.059,8.561,8.054,7.819,8.203,8.622,7.983,7.401,8.733,8.519,6.158,None,None,8.573,7.841,7.385,8.672,8.897,9.201,9.065,None,8.071,8.062,8.726,8.695,8.188,8.205,None,7.474,8.807,8.294,8.342,7.746,7.478,8.115,7.126,8.812,7.882,8.234,9.25,7.809,9.339,8.435,9.186,8.939,8.337,9.181,8.473,8.582,None,None]


print(len(ExpData_CA))
print(len(ExpData_C))
print(len(ExpData_CB))
print(len(ExpData_N))
print(len(ExpData_HA))
print(len(ExpData_HN))
# Out:
# 76
# 76
# 76
# 76
# 76
# 76

# %%
Avg_CAShift = AvgChemShift_CA("5xk4.md.pdb_pred_sim1.tab","5xk4.md.pdb_pred_sim2.tab","5xk4.md.pdb_pred_sim3.tab","5xk4.md.pdb_pred_sim4.tab","5xk4.md.pdb_pred_sim5.tab")
Avg_CAShift_CMAP = AvgChemShift_CA("5xk4.md.pdb_pred_CMAP_sim1.tab","5xk4.md.pdb_pred_CMAP_sim2.tab","5xk4.md.pdb_pred_CMAP_sim3.tab","5xk4.md.pdb_pred_CMAP_sim4.tab","5xk4.md.pdb_pred_CMAP_sim5.tab")
Avg_CAShift_D = AvgChemShift_CA("5xk4.md.pdb_pred_D_sim1.tab","5xk4.md.pdb_pred_D_sim2.tab","5xk4.md.pdb_pred_D_sim3.tab","5xk4.md.pdb_pred_D_sim4.tab","5xk4.md.pdb_pred_D_sim5.tab")
Avg_CAShift_D_CMAP = AvgChemShift_CA("5xk4.md.pdb_pred_D_CMAP_sim1.tab","5xk4.md.pdb_pred_D_CMAP_sim2.tab","5xk4.md.pdb_pred_D_CMAP_sim3.tab","5xk4.md.pdb_pred_D_CMAP_sim4.tab","5xk4.md.pdb_pred_D_CMAP_sim5.tab")

print('ffptm EW CA ',RMSD(Avg_CAShift,ExpData_CA))
print('ff03CMAP EW CA ',RMSD(Avg_CAShift_CMAP,ExpData_CA))
print('ffptm D CA ',RMSD(Avg_CAShift_D,ExpData_CA))
print('ff03CMAP D CA ',RMSD(Avg_CAShift_D_CMAP,ExpData_CA))



Avg_CShift = AvgChemShift_C("5xk4.md.pdb_pred_sim1.tab","5xk4.md.pdb_pred_sim2.tab","5xk4.md.pdb_pred_sim3.tab","5xk4.md.pdb_pred_sim4.tab","5xk4.md.pdb_pred_sim5.tab")
Avg_CShift_CMAP = AvgChemShift_C("5xk4.md.pdb_pred_CMAP_sim1.tab","5xk4.md.pdb_pred_CMAP_sim2.tab","5xk4.md.pdb_pred_CMAP_sim3.tab","5xk4.md.pdb_pred_CMAP_sim4.tab","5xk4.md.pdb_pred_CMAP_sim5.tab")
Avg_CShift_D = AvgChemShift_C("5xk4.md.pdb_pred_D_sim1.tab","5xk4.md.pdb_pred_D_sim2.tab","5xk4.md.pdb_pred_D_sim3.tab","5xk4.md.pdb_pred_D_sim4.tab","5xk4.md.pdb_pred_D_sim5.tab")
Avg_CShift_D_CMAP = AvgChemShift_C("5xk4.md.pdb_pred_D_CMAP_sim1.tab","5xk4.md.pdb_pred_D_CMAP_sim2.tab","5xk4.md.pdb_pred_D_CMAP_sim3.tab","5xk4.md.pdb_pred_D_CMAP_sim4.tab","5xk4.md.pdb_pred_D_CMAP_sim5.tab")

print('\nffptm EW C ',RMSD(Avg_CShift,ExpData_C))
print('ff03CMAP EW C ',RMSD(Avg_CShift_CMAP,ExpData_C))
print('ffptm D C ',RMSD(Avg_CShift_D,ExpData_C))
print('ff03CMAP D C ',RMSD(Avg_CShift_D_CMAP,ExpData_C))


Avg_CShift = AvgChemShift_C("5xk4.md.pdb_pred_sim1.tab","5xk4.md.pdb_pred_sim2.tab","5xk4.md.pdb_pred_sim3.tab","5xk4.md.pdb_pred_sim4.tab","5xk4.md.pdb_pred_sim5.tab")
Avg_CShift_CMAP = AvgChemShift_C("5xk4.md.pdb_pred_CMAP_sim1.tab","5xk4.md.pdb_pred_CMAP_sim2.tab","5xk4.md.pdb_pred_CMAP_sim3.tab","5xk4.md.pdb_pred_CMAP_sim4.tab","5xk4.md.pdb_pred_CMAP_sim5.tab")
Avg_CShift_D = AvgChemShift_C("5xk4.md.pdb_pred_D_sim1.tab","5xk4.md.pdb_pred_D_sim2.tab","5xk4.md.pdb_pred_D_sim3.tab","5xk4.md.pdb_pred_D_sim4.tab","5xk4.md.pdb_pred_D_sim5.tab")
Avg_CShift_D_CMAP = AvgChemShift_C("5xk4.md.pdb_pred_D_CMAP_sim1.tab","5xk4.md.pdb_pred_D_CMAP_sim2.tab","5xk4.md.pdb_pred_D_CMAP_sim3.tab","5xk4.md.pdb_pred_D_CMAP_sim4.tab","5xk4.md.pdb_pred_D_CMAP_sim5.tab")
# Out:
# ffptm EW CA  0.9639407345466376
# ff03CMAP EW CA  0.9796698124411374
# ffptm D CA  0.9594814852634629
# ff03CMAP D CA  0.9072437733185901
#
# ffptm EW C  1.1985817318814775
# ff03CMAP EW C  1.156135223658813
# ffptm D C  1.2193707004970937
# ff03CMAP D C  1.1426146539339541
